# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %% [markdown]
# # B(E3) Strengths

# %%
from pypdf import PdfReader 

FILES = !ls *.pdf

for file in FILES:
    
    reader = PdfReader(file)
    
    for i in range(len(reader.pages)):
        
        page = reader.pages[i] 
        text = page.extract_text() 

        if "B(E3)" in text:
            print(file)

            print("================================================================================")
            print("================================================================================")
            print(text) 
            
            #break
# Out:
# 12C6.pdf
# ================================================================================
# ================================================================================
# Continued on next page (footnotes at end of table)12
# 6C6-9 From ENSDF12
# 6C6-9
# Adopted Levels ,Gammas 2017Ke05 (continued)
# 12C Levels (continued)
# E(level) JπT1/2 XREF Comments
# andΓα0/Γ=0.105 30.
# Partial widths from ( 1979Fr04 ).
# 27.8×1032≈350 keV F P S XREF: Others:AA
# %IT>0; %n<100; %p<100; %3He<100; %α<100
# E(level): From ( 1969Gu05 ).
# Γ: From ( 1963Du12 ,1965Di06 ).
# 28200 1−1.6 MeV E %IT>1.7×10−3; %3He≈100
# T=1
# E(level),Γ: From ( 1972Bl17 ).
# 28830 40 1.54 MeV 9E L P XREF: Others:AI,AJ,AK
# %IT>0; %p<100; %d<100; %3He<100; %α<100
# E(level): From ( 1972Li29 ,1974Sh01 ).
# 29.4×1033 (2+)≈800 keV F P YZ XREF: Others:AE
# %IT>0; %n<100; %p<100; %3H<100; %3He<100
# T=(1)
# E(level): From ( 1977Bu19 ).
# Γ: From ( 2008Af04 ).
# 29630 50≤200 keV XREF: Others:BA
# %α≈20; %p=80
# T=2
# E(level),Γ: From ( 1976As01 )Γp/Γ=0.8
# 2,Γp0/Γ=0.4,Γα/Γ≈0.2.
# 30290 30 (2+,2−) 1.54 MeV 9C E XREF: Others:AA
# %IT>0; %3He<100; %α<100
# T=(0,1)
# E(level),Γ: From ( 1972Li29 ,1974Sh01 ).
# 31160 30 2.10 MeV 15E %IT>0; %3He<100
# E(level),Γ: From ( 1972Li29 ,1974Sh01 ).
# 32290 40 1.32 MeV 23C E XREF: Others:AA
# %IT>0; %n<100; %p<100; %3He<100
# Also decays via6Li emission.
# E(level),Γ: From ( 1972Li29 ,1974Sh01 ).
# 33.47×10321 1.93 MeV 5E %IT>0; %3He<100
# E(level),Γ: From ( 1972Li29 ,1974Sh01 ).
# †See discussion on the charge-dependent matrix element betw een12C*(12710,15110) in Table 12.18 ( 2017Ke05 ).
# ‡See discussion in ( 1983Ne11 ).
# #Decay mode not speciﬁed.
# γ(12C)
# Ei(level) Jπ
# iEγ†Iγ Ef Jπ
# fMult. Comments
# 4439.82 2+4438.94 100 0 0+E2Γγ=10.8×10−3eV6; B(E2)(W.u.)=4.65 26
# 7654.07 0+3213.79 100 4439.82 2+E2Γγ=3.81×10−3eV39; B(E2)(W.u.)=8.26 85
# 9641 3−9637 100 0 0+E3Γγ=3.1×10−4eV4(1967Cr01 ); B(E3)(W.u.)=122
# 12710 1+8267 15 3 4439.82 2+M1Γγ=5.3×10−2eV10; B(M1)(W.u.)=4.5×10−38
# 12703 100 14 0 0+M1Γγ=0.35 eV 5; B(M1)(W.u.)=8.1×10−312
# Γγ1fromΓγ1/Γγ0=0.150 18(1977Ad02 ). See also
# (1972Al03 ) who found Iγ(12.1 MeV→0)=(154)% and Iγ(12.1
# MeV→4.44 MeV)=(854)%, which implies Γγ1/Γγ0=0.17 5.
# 15110 1+2400‡1.5412710 1+M1Γγ=0.59 eV 17; B(M1)(W.u.)=2.06
# 9
# 12C6.pdf
# ================================================================================
# ================================================================================
# Continued on next page (footnotes at end of table)12
# 6C6-10 From ENSDF12
# 6C6-10
# Adopted Levels ,Gammas 2017Ke05 (continued)
# γ(12C) (continued)
# Ei(level) Jπ
# iEγ†Iγ Ef Jπ
# fMult. Comments
# 15110 1+4809 4.2 15 10.3×103?(0+)Γγ=1.6 eV 6
# 7453‡2.83 36 7654.07 0+M1Γγ=1.09 eV 14; B(M1)(W.u.)=0.13 2
# 10665‡2.49 34 4439.82 2+M1Γγ=0.96 eV 13; B(M1)(W.u.)=3.8×10−25
# 15100 100 2 0 0+M1Γγ=38.5 eV 8; B(M1)(W.u.)=0.531 11
# 16106.0 2+3396 1.5 3 12710 1+M1Γγ=0.19 eV 4; B(M1)(W.u.)=0.23 5
# 5257 3.8 9 10847 1−E1Γγ=0.48 eV 12
# 6463 2.4 5 9641 3−E1Γγ=0.31 eV 6; B(E1)(W.u.)=3.2×10−36
# 11660.1 100 12 4439.82 2+M1Γγ=12.8 eV 15; B(M1)(W.u.)=0.38 5
# 16094.4 4.6 9 0 0+E2Γγ=0.59 eV 11; B(E2)(W.u.)=0.40 8
# 16620 2−12180 100 4439.82 2+Γγ=8 eV; B(E1)(W.u.)=1.2×10−2
# 16608 0.60 1 0 0+M2Γγ=4.80×10−2eV8; B(M2)(W.u.)=0.48 8
# 17230 1−12783 11 4439.82 2+Γγ=5 eV; B(E1)(W.u.)=6.7×10−3
# 17217 100 0 0+Γγ=44 eV; B(E1)(W.u.) =2.4×10−2
# Iγ: From ( 1965Se06 ).
# 17760 0+5049 100 12710 1+Γγ=3.7 eV 15; B(M1)(W.u.)=1.46
# 18160 (1+) 3049 100 15110 1+
# 18350 3−8706 100 9641 3−Γγ=5.7 eV 23; B(M1)(W.u.)=0.41 2
# Iγ: From ( 1965Se06 ).
# 13902 56 4439.82 2+Γγ=3.2 eV; B(E1)(W.u.) =3.3×10−3
# 18335 3.5×10−40 0+Γγ<1.5 eV; B(E3)(W.u.) <6.5×102
# 18800 2+14351 100 4439.82 2+Γγ=2 eV; B(M1)(W.u.) =3.2×10−2
# Iγ: From ( 1965Se06 ).
# 18784<20 0 0+Γγ≈0.4 eV; B(E2)(W.u.) ≈0.13
# 19.2×103(1−) 14.75×10340 4439.82 2+Γγ=10 eV
# 19.2×103100 0 0+Γγ=25 eV
# Iγ: From ( 1965Se06 ).
# 19400 2−14950 100 4439.82 2+Iγ: From ( 1965Se06 ).
# 20553 (3+) 20534 0 0+
# 20600 (3−) 20581 0 0+
# 21.60×103(2+,3−) 21.58×1030 0+
# 21990 1−21968 0 0+
# 22.65×1031−22.63×1030 0+
# 23530 1−19074 4439.82 2+
# 23505 0 0+
# 24.41×1039.29×10315110 1+
# 25.40×103(1−) 20.94×1034439.82 2+
# 25.37×1030 0+
# 26800 19130 7654.07 0+
# 22338 4439.82 2+
# 27595.0 0+12478 15110 1+
# 27.8×10323.3×1034439.82 2+
# 27.8×1030 0+
# 28200 1−20.52×1037654.07 0+
# 28.16×1030 0+
# 28830 21156 7654.07 0+
# 28793 0 0+
# 29.4×103(2+) 29.4×1030 0+
# 30290 (2+,2−) 25.82×1034439.82 2+
# 31160 31.12 ×1030 0+
# 32290 24.61 ×1037654.07 0+
# 27.82×1034439.82 2+
# 10
# 14C6.pdf
# ================================================================================
# ================================================================================
# 14
# 6C8-3 From ENSDF14
# 6C8-3
# Adopted Levels ,Gammas 1991Aj01 (continued)
# γ(14C)
# Ei(level) Jπ
# iEγ Iγ Ef Jπ
# fMult. I (γ+ce) Comments
# 6093.8 1−6092.4 2 100 0.0 0+[E1] B(E1)(W.u.) >7.3×10−4
# 6589.4 0+495.35 10 100.0 1 6093.8 1−[E1] B(E1)(W.u.) =0.0032 4
# 6587.7 2 0.0 0+[E0] 1.1 1 I(γ+ce): this decay mode is due entirely to internal
# pairs.
# 6728.2 3−634.4 13 3.713 6093.8 1−[E2] B(E2)(W.u.) =1.56
# 6726.5 13 100.1 13 0.0 0+[E3] B(E3)(W.u.) =2.43
# 6902.6 0−808.8 3 100 6093.8 1−[M1] B(M1)(W.u.) =1.62
# 7012 2+9184 1.47 6093.8 1−[E1] B(E1)(W.u.) =0.0023 12
# 7010 4 100.0 7 0.0 0+[E2] B(E2)(W.u.) =1.83
# 7341 2−6133 707 6728.2 3−[M1] B(M1)(W.u.) =0.29 10
# δ:δ(E2/M1)=−0.07 30.
# 1248 3 1007 6093.8 1−[M1] B(M1)(W.u.) =0.049 20
# δ:δ(E2/M1)=0.04 9.
# 7339 3 347 0.0 0+[M2] B(M2)(W.u.) =0.38 15
# 11306 1+11301 15 100 0.0 0+[M1] B(M1)(W.u.) =0.22 5
# 3
# 168Er68.pdf
# ================================================================================
# ================================================================================
# 168
# 68Er100-18 From ENSDF168
# 68Er100-18Adopted Levels ,Gammas (continued)
# γ(168Er)
# Ei(level) JπiEγ†Iγ‡Ef Jπ
# fMult.†δ†αfComments
# 79.804 2+79.804 1100 0.0 0+E2 7.04 B(E2)(W.u.) =2134
# 264.0888 4+184.285 1100 79.804 2+E2 0.331 B(E2)(W.u.) =3199
# 548.7470 6+284.655 2100 264.0888 4+E2 0.0811 B(E2)(W.u.) =42418
# 821.1685 2+557.079 3 1.74d8 264.0888 4+E2c0.01252 B(E2)(W.u.) =0.61 4
# 741.356 3100d2 79.804 2+E2+M1b>25b#0.00639 9 B(M1)(W.u.)<1.6×10−5; B(E2)(W.u.)>8.0
# 821.164 5 93.6d4 0.0 0+E2 0.00510 8 B(E2)(W.u.)=4.68 16
# 895.7947 3+74.626 3 0.04 1 821.1685 2+M1+E2+1.42+4−5 8.35 13 B(M1)(W.u.)=0.0018+5−7; B(E2)(W.u.)=3.1×102+8−12
# δ: sign fromγγ(θ) (1996Al31 ) inεdecay; magnitude
# from L1/L3 in (n,γ) E=thermal ( 1980Sc15 ).
# 631.703 3 18.1d2 264.0888 4+M1+E2−4.8@2 0.00965 14 B(M1)(W.u.)=0.000172+18−51; B(E2)(W.u.)=4.6+3−14
# 815.990 4100d2 79.804 2+M1+E2+17.7&23 0.00518 8 B(M1)(W.u.)=3.4×10−5+9−13; B(E2)(W.u.)=7.4+5−21
# 928.3029 8+379.545 3100 548.7470 6+E2 0.0346 B(E2)(W.u.) =35413
# 994.7474 4+(98.95) 895.7947 3+B(E2)(W.u.)=505+122−40
# B(E2)(W.u.): From measured B(E2) in Coulomb excitation.Eγ: from level energy di ﬀerence. Existence implied in
# Coulomb excitation; possibly obscured in (n, γ)
# E=thermal by 99γfrom 1193 level.
# 173.577 1 0.80d5 821.1685 2+E2 0.406 B(E2)(W.u.) =9220
# 445.995 4 1.1d1 548.7470 6+[E2] 0.0222 B(E2)(W.u.) =1.13 25
# 730.660 2100d2 264.0888 4+M1+E2+13+16−3 0.00664 10 B(M1)(W.u.)=6.E−5+15−6; B(E2)(W.u.)=8.618
# Mult.,δ: D+Q fromγ(θ) in (n,n′γ);∆πfrom ce data in
# (n,γ).
# 914.944 6 59.1d3 79.804 2+E2 0.00404 6 B(E2)(W.u.)=1.74
# 1094.0383 4−99.289 2 7.77d8 994.7474 4+E1+M2b−0.06b5 0.43 23 B(E1)(W.u.)=1.2×10−73; B(M2)(W.u.)=0.20+34−20
# 198.241 1100d2 895.7947 3+E1+M2b−0.12b3 0.084 18 B(E1)(W.u.)=1.94×10−78; B(M2)(W.u.)=0.33 17
# 272.876 2 0.17d1 821.1685 2+M2 0.754 B(M2)(W.u.) =0.0079 6
# 829.958 7 12.8d1 264.0888 4+E1+M2b−0.05b3 0.00201 10 B(E1)(W.u.)=3.43×10−1010; B(M2)(W.u.)=6×10−6+7−6
# 1014.11 4 0.135d5 79.804 2+M2+E3b−0.55b2 0.01304 21 B(M2)(W.u.)=6.8×10−64; B(E3)(W.u.)=0.00142 11
# 1117.5703 5+122.821 1 0.38 6 994.7474 4+M1+E2 1.57+7−9 1.434 21 B(M1)(W.u.)=0.0044+9−17; B(E2)(W.u.)=3.4×102+7−13
# 221.775 2 3.63 895.7947 3+E2 0.179 B(E2)(W.u.) =2.4×102+4−9
# 568.821 6 16.2 8 548.7470 6+E2+M1 3.6 3 0.01284 25 B(M1)(W.u.)=0.00047+10−18; B(E2)(W.u.)=8.9+11−31
# 853.473 61009 264.0888 4+M1+E2 3.6+24−8 0.00500 21 B(M1)(W.u.)=0.0009+11−9; B(E2)(W.u.)=7.2+13−27
# 1193.0251 5−75.466 7 0.28 8 1117.5703 5+E1 0.682 B(E1)(W.u.) =4.4×10−715
# Mult.: fromα(K)exp inεdecay.
# 98.982 210015 1094.0383 4−E2 3.06 B(E2)(W.u.) =33080
# Eγ,Iγ: possibly includes contribution from an expected γ
# from 995 level.
# 18
# 168Er68.pdf
# ================================================================================
# ================================================================================
# 168
# 68Er100-20 From ENSDF168
# 68Er100-20Adopted Levels ,Gammas (continued)
# γ(168Er) (continued)
# Ei(level) JπiEγ†Iγ‡Ef Jπ
# fMult.†δ†αfComments
# 1403.7357 (2)−507.936 3 3.24 895.7947 3+
# 582.567 3 31.9 20 821.1685 2+E1 0.00401 6
# 1323.913 20 1004 79.804 2+E1 δ(D,Q)=+0.05+11−6from (n,n′γ).
# 1411.0959 4+134.824 1 5.813 1276.2716 2+
# 293.523 2 1.05 21 1117.5703 5+M1+E2 1.4+14−5 0.097 16 B(M1)(W.u.)<0.0030; B(E2)(W.u.) <23
# 416.352 4 14.1 11 994.7474 4+M1+E2 1.7+11−5 0.034 5 B(M1)(W.u.)<0.0089; B(E2)(W.u.) <47
# 515.303 2 19.7 23 895.7947 3+E2 0.01522 B(E2)(W.u.) <23
# 589.913 8 3.25 821.1685 2+E2 0.01088 B(E2)(W.u.) <1.9
# 862.355 11 814 548.7470 6+E2 0.00459 7 B(E2)(W.u.)<7.2
# 1146.998 9 674 264.0888 4+M1 0.00443 7 B(M1)(W.u.)<0.0040
# 1331.324 15 1008 79.804 2+E2 0.00193 3 B(E2)(W.u.)<1.0
# 1422.12 0+205.1 1217.169 0+E0 E γ,Mult.: fromεdecay.
# 1342.44 7 100 79.804 2+E2 0.00190 3
# 1422.2 0.0 0+E0 E γ,Mult.: fromεdecay.
# 1431.466 3−535.642g21<0.41g895.7947 3+[E1] 0.00480 7 B(E1)(W.u.)=3.62×10−8
# 1167.396 15 1008 264.0888 4+E1 1.04 ×10−3B(E1)(W.u.)=1.70×10−6
# 1351.54 4 994 79.804 2+E1 8.93 ×10−4B(E1)(W.u.)=1.09×10−6
# 1431.7d4 0.50d18 0.0 0+[E3] 0.00328 5 B(E3)(W.u.)=3.58
# B(E3)(W.u.)=3.75from measured B(E3) =0.043 6
# in Coulomb excitation ( 1978Mc02 ).
# 1432.9508 7+169.043 3 1.07 21 1263.9047 6+M1+E2 1.5+4−2 0.505 20 B(E2)(W.u.)=198+87−183
# δ: estimate from (n, γ) E=thermal based on Alaga
# rule.
# B(E2)↓: From measured B(E2) in Coulomb
# excitation.
# 315.383 3 37.2 24 1117.5703 5+E2 0.0594 B(E2)(W.u.) =380+14−176
# B(E2)↓: From measured B(E2) in Coulomb
# excitation.
# 504.644 4 14.1 17 928.3029 8+M1+E2<0.22 0.0337 7 B(E2)(W.u.)=17+14−7
# Mult.,δ:α(K)exp in (n,γ) E=thermal implies
# δ<0.22, but measured B(E2) requires nonzero E2
# component.
# B(E2)↓: From measured B(E2) in Coulomb
# excitation.
# 884.219 9 10010 548.7470 6+M1+E2 1.3+8−4 0.0058 8 B(E2)(W.u.)=12+7−5
# B(E2)↓: From measured B(E2) in Coulomb
# excitation.
# 1448.9555 7−137.494 1 14.0 22 1311.4606 6−E2 0.916 I γ: unweighted average of 11.5 14from 1991DaZT
# in (n,γ) E=thermal and 16.1 13from
# 170Er(136Xe,Xγ). Other Iγ: 16.2 25
# (2007ChZX ) from (n,γ) E=thermal for probable
# doublet.
# 20
# 168Er68.pdf
# ================================================================================
# ================================================================================
# 168
# 68Er100-21 From ENSDF168
# 68Er100-21Adopted Levels ,Gammas (continued)
# γ(168Er) (continued)
# Ei(level) JπiEγ†Iγ‡Ef Jπ
# fMult.†δ†αfComments
# 1448.9555 7−185.056 5 0.72 16 1263.9047 6+
# 255.929 1 1004 1193.0251 5−E2 0.1130
# 520.667 9 1.63 928.3029 8+
# 900.206 15 13.5 18 548.7470 6+
# 1493.133 2+70.9 1422.12 0+(E2) 11.35 E γ,Mult.: from L2/L3 inεdecay.
# 498.46 6 1.45 994.7474 4+
# 597.327 7 5.510 895.7947 3+
# 671.961 9 6.712 821.1685 2+
# 1229.080 15 1007 264.0888 4+E2 0.00223 4
# 1413.317 23 846 79.804 2+M1+E2+0.74 0.00241 25 Mult.,δ:α(K)exp consistent with M1 in
# (n,γ); D+Q from (n,n′γ) withδ=+0.74.
# 1493.09 8 224 0.0 0+E2 1.59 ×10−3
# 1541.5564 3−110.2i1431.466 3−M1(+E2) 2.10 7 Eγ,Mult.: fromεdecay.
# 348.523 2 1.48d3 1193.0251 5−E2 0.0442 B(E2)(W.u.) =2.02
# 447.515 3 100d2 1094.0383 4−M1+E2b−0.09b1 0.0463 B(M1)(W.u.) =0.0167; B(E2)(W.u.) =0.31 7
# 546.802 5 11.1d2 994.7474 4+E1(+M2)b+0.007b23 0.00460 10 B(E1)(W.u.)=1.03×10−5;
# B(M2)(W.u.)=0.008+51−8
# 645.775 15 6.26d6 895.7947 3+E1 0.00323 5 B(E1)(W.u.)=3.53×10−6
# Other Iγ: 8.2 11fromβ−decay, 17 3from
# (n,γ) E=thermal.
# 720.392 5 51.0d5 821.1685 2+E1+M2b−0.012b10 0.00259 4 B(E1)(W.u.)=2.07×10−5; B(M2)(W.u.)=0.03
# +5−3
# 1277.451d5 7.04d7 264.0888 4+E1+M2b−0.040b18 9.47×10−419 B(E1)(W.u.)=5.1×10−7;
# B(M2)(W.u.)=0.0023 21
# 1461.750d4 1.03d1 79.804 2+[E1] 8.66 ×10−413 B(E1)(W.u.)=5.0×10−8
# 1541.46 25 0.0096d5 0.0 0+[E3] 0.00282 4 B(E3)(W.u.)=0.230
# 1541.7094 (4)−110.245 4 0.31 6 1431.466 3−
# 137.974 4 1.63 1403.7357 (2)−E2 0.904
# 546.960 5 286 994.7474 4+[E1]
# 645.939 11 173 895.7947 3+[E1]
# 1277.592 20 10013 264.0888 4+E1 9.35 ×10−413
# 1569.4527 (2)−27.80 1541.5564 3−M1,E2 5 ×1025 Eγ,Mult.: fromεdecay.
# 165.3 1403.7357 (2)−M1(+E2) 0.58 11 Eγ,Mult.: fromεdecay.
# 673.666 4 38d2 895.7947 3+E1 0.00296 5 B(E1)(W.u.)=0.00046+9−13
# 748.281 4 100d2 821.1685 2+E1 0.00239 4 B(E1)(W.u.)=0.00089+17−23
# 1489.66d3 0.50d3 79.804 2+
# 1569.5d4 0.005d2 0.0 0+[M2] B(M2)(W.u.)=0.009+4−5
# 1574.117 5−1025.377 11 584 548.7470 6+E1 1.31 ×10−3
# 21
# 168Er68.pdf
# ================================================================================
# ================================================================================
# 168
# 68Er100-23 From ENSDF168
# 68Er100-23Adopted Levels ,Gammas (continued)
# γ(168Er) (continued)
# Ei(level) JπiEγ†Iγ‡Ef Jπ
# fMult.†αfComments
# 1633.4627 3−638.710 8 799 994.7474 4+E1 0.00330 5B(E1)(W.u.)=0.00072+19−25
# 737.686 4 1005 895.7947 3+E1 0.00246 4B(E1)(W.u.)=0.00059+15−19
# 812.287 11 8911 821.1685 2+
# 1553.5d7 0.4d2 79.804 2+
# (1633.46) 0.0 0+B(E3)↓=4.39
# B(E3)↓: From measured B(E3) =0.050 10in Coulomb excitation.
# 1653.5486 3+84.096 3 0.69 19 1569.4527 (2)−E1 0.514
# 111.985 13 0.070 25 1541.5564 3−
# 249.809 3 0.26 5 1403.7357 (2)−
# 559.510 4 1004 1094.0383 4−E1 0.00437
# 757.84 3 0.94 25 895.7947 3+M1 0.01220
# 832.36 4 10.1 19 821.1685 2+
# 1656.274 (4)+163.137g2<1.06g1493.133 2+
# 538.68g3<1.9g1117.5703 5+Mult.: E2 fromα(K)exp in (n,γ) E=thermal for doubly-placed γ.
# 661.523 7 2.85 994.7474 4+M1 0.01713
# 760.54 9 1.43 895.7947 3+
# 835.14 3 2.39 821.1685 2+
# 1107.495 19 373 548.7470 6+E2 0.00273 4
# 1392.209 13 1005 264.0888 4+M1 0.00283 4
# 1576.58g8<11.3g79.804 2+
# 1707.9929 5−92.652 1 14.0 21 1615.3420 4−M1 3.54
# 166.434 1 3.16 1541.5564 3−
# 259.034 5 0.50 10 1448.9555 7−
# 396.530 3 1006 1311.4606 6−M1 0.0637
# 444.086 4 11.5 17 1263.9047 6+
# 514.970 2 18.1 19 1193.0251 5−
# 590.415 12 3.16 1117.5703 5+
# 613.951 4 16.0 25 1094.0383 4−M1 0.0207
# 713.257 6 955 994.7474 4+E1 0.00263 4
# 1719.1786 4−601.603 5 565 1117.5703 5+E1 0.00374 6
# 724.432 5 383 994.7474 4+E1 0.00255 4
# 823.386 8 1007 895.7947 3+E1 0.00198 3
# 1736.6881 4+83.138 2 1.63 1653.5486 3+E2 5.99
# 103.228 4 0.89 22 1633.4627 3−
# 194.992 8 0.09 3 1541.7094 (4)−
# 305.219 5 0.46 6 1431.466 3−
# 543.667 7 1004 1193.0251 5−E1 0.00465 7
# 642.629 20 2.06 1094.0383 4−
# 741.0 16 994.7474 4+
# 840.890 8 1.11 22 895.7947 3+E2 0.00484 7
# 1472.81 11 6.715 264.0888 4+
# 23
# 16O8.pdf
# ================================================================================
# ================================================================================
# Continued on next page (footnotes at end of table)16
# 8O8-5 From ENSDF16
# 8O8-5
# Adopted Levels ,Gammas 1993Ti07 (continued)
# 16O Levels (continued)
# E(level) JπT1/2 XREF Comments
# 2735×10110 (2,4)+830 keV 110B F %IT=?; %p=?; %3He=?; %α=?; %8Be=?
# T=1
# 27500 (3−)≈2500 keV B %IT=?; %3He=100
# T=(0)
# 28200 7−1000 keVA %α=100
# 2860×10120 B %IT=?; %3He=100
# 29000 7−1000 keVA %p=?; %α=?
# 2980×10110 9−& 8+750 keV 250B %3He=?; %α=?
# T1/2: author quotesΓ=500-1000.
# 3180×10160 %IT=?; %α=?
# 34000 10+,(9−) 2300 keV A %α=100
# 35000 A %α=100
# †Decay mode not speciﬁed.
# ‡π=even.
# γ(16O)
# Ei(level) Jπ
# iEγ Iγ Ef Jπ
# fMult.δ‡I(γ+ce) Comments
# 6049.4 0+6048.2 10 0.0 0+[E0] 100
# 6129.89 3−6128.63 4 100 0.0 0+[E3] B(E3)(W.u.) =13.5 7
# 6917.1 2+787.2 6≤0.008 6129.89 3−[E1] B(E1)(W.u.) ≤4×10−5
# 867.7 12 0.027 3 6049.4 0+[E2] B(E2)(W.u.) =273
# 6915.5 6 100 0.0 0+[E2] B(E2)(W.u.) =3.11
# 7116.85 1−986.93 15 0.070 14 6129.89 3−[E2] B(E2)(W.u.) =215
# 1067.5 10<6×10−46049.4 0+[E1] B(E1)(W.u.) ≤6×10−7
# 7115.15 14 100 0.0 0+[E1] B(E1)(W.u.) =3.5×10−42
# 8871.9 2−1754.9 6 14.7 7 7116.85 1−[M1+E2] 2.1 4 B(M1)(W.u.)=7×10−43;
# B(E2)(W.u.)=10.3 15
# 1954.7 8 4.67 6917.1 2+[E1] B(E1)(W.u.) =4.7×10−59
# 2741.5 5 10021 6129.89 3−[M1+E2] 2.9 2 B(M1)(W.u.)=6.9×10−49;
# B(E2)(W.u.)=8.27
# 2822.2 12 0.15 5 6049.4 0+[M2] B(M2)(W.u.) =0.18 6
# 8869.3 5 9.310 0.0 0+[M2] B(M2)(W.u.) =0.050 8
# 9585 1−2688 11 124 6917.1 2+[E1] B(E1)(W.u.) =3.5×10−412
# 9582 11 10016 0.0 0+[E1] B(E1)(W.u.) =6.6×10−511
# 9844.5 2+2927.1 8 347 6917.1 2+[M1] B(M1)(W.u.) =0.0042 8
# 3794.6 12 307 6049.4 0+[E2] B(E2)(W.u.) =1.23
# 9841.2 5 1007 0.0 0+[E2] B(E2)(W.u.) =0.031 3
# 10356 4+3439 3 10010 6917.1 2+[E2] B(E2)(W.u.) =656
# 4225 3<1.6 6129.89 3−[E1] B(E1)(W.u.) <3×10−5
# 10352 3 9×10−53 0.0 0+[E4] B(E4)(W.u.) =3.713
# 10957 0−3839.6 10 100 7116.85 1−[M1] B(M1)(W.u.) =0.07 4
# 11096.7 4+4179.0 17 8120 6917.1 2+[E2] B(E2)(W.u.) =1.03
# 4966.0 16 10042 6129.89 3−[E1] B(E1)(W.u.) =5.9×10−525
# 11520 2+4402 4≤0.9 7116.85 1−[E1] B(E1)(W.u.) ≤1×10−4
# 4602 4 4.411 6917.1 2+[M1] B(M1)(W.u.) =0.014 4
# 5470 5 4.68 6049.4 0+[E2] B(E2)(W.u.) =3.15
# 11516 4 100.0 13 0.0 0+[E2] B(E2)(W.u.) =1.55
# 12049 0+12044.1 20 0.0 0+[E0] 100
# 12440 1−6389.2 23 1.24 6049.4 0+[E1] B(E1)(W.u.) =0.0011 4
# 5
# 20Ne10.pdf
# ================================================================================
# ================================================================================
# Continued on next page (footnotes at end of table)20
# 10Ne10-8 From ENSDF20
# 10Ne10-8
# Adopted Levels ,Gammas 1998Ti06 (continued)
# 20Ne Levels (continued)
# E(level) JπT1/2 XREF Comments
# T=0
# 20468 30 5−280 keV 70E %α=100
# T=0
# 20686 6 9−78 keV 11C E G %α=100
# T=0
# 20760 30 7−240 keV 50EF %α=100
# T=0
# 20800 25 5−170 keV 60E %α=100
# T=0
# 20950 40 7−300 keV 50C E %α=100
# T=0
# 21062 6 9−60 keV 6C E GH %α=100
# T=0
# 2130×10110 7−300 keV EF %α=100
# T=0
# 2180×10110 7−300 keVC EF %α=100
# T=0
# 2230×10110 7−500 keVC EF %α=100
# T=0
# 2260×10130 %IT=?; %n=?
# T1/2:Γ=broad.
# 22800 60 9−500 keVC E %α=100
# T=0
# 22870 40 9−225 keV 40C E GH %α=100
# T=0
# 2340×10120 8+500 keV E %α=100
# T=0
# 23700 30 (9−)≤200 keV FG %α=100
# 24210 25 8+350 keV E G %α=100
# T=0
# 2490×10150 %IT=?; %n=?
# T1/2:Γ=broad.
# 25100 50 8+≈200 keV E G %α=100
# T=0
# 25670 50≈400 keV E G %α=100
# 2710×10110 (9−) 700 keV EF H %α=100
# 27500 10+%IT=?; %n=?
# T1/2:Γ=broad.
# 28000 8+1600 keV E %α=100
# T=0
# 2820×10130 700 keV E %α=100
# γ(20Ne)
# Ei(level) Jπ
# iEγ Iγ Ef Jπ
# fMult. Comments
# 1633.674 2+1633.602 15 100 0.0 0+[E2] B(E2)(W.u.) =20.3 10
# 4247.7 4+2613.8 11 100 1633.674 2+[E2] B(E2)(W.u.) =222
# 4966.51 2−3332.54 20 99.4 2 1633.674 2+[E1+M2+E3] B(E1)(W.u.) =7.3×10−68; B(M2)(W.u.)=0.017 4;
# B(E3)(W.u.)=62
# δ(M2/E1)=0.076 11,δ(E3/E1)=0.043 16.
# 4965.85 20 0.62 0.0 0+[M2] B(M2)(W.u.) =0.0025 8
# 5621.4 3−654.9 18 4.816 4966.51 2−[M1] B(M1)(W.u.) =2.0×10−39
# 3987.3 17 87.6 10 1633.674 2+[E1] B(E1)(W.u.) =6.6×10−619
# 8
# 20Ne10.pdf
# ================================================================================
# ================================================================================
# Continued on next page (footnotes at end of table)20
# 10Ne10-9 From ENSDF20
# 10Ne10-9
# Adopted Levels ,Gammas 1998Ti06 (continued)
# γ(20Ne) (continued)
# Ei(level) Jπ
# iEγ Iγ Ef Jπ
# fMult.δ Comments
# 5621.4 3−5620.6 17 7.610 0.0 0+[E3] B(E3)(W.u.) =114
# 5787.7 1−4154 3 825 1633.674 2+[E1] B(E1)(W.u.) =1.1×10−42
# 5787 3 185 0.0 0+[E1] B(E1)(W.u.) =8.3×10−63
# 6725 0+5090 5 100 1633.674 2+[E2] B(E2)(W.u.) =3.6
# 6724 5 0.0 0+[E0]
# 7004.0 4−1383 4 25 5621.4 3−[M1] B(M1)(W.u.) =6.9×10−3
# 2037 4 11 4966.51 2−[E2] B(E2)(W.u.) =1.8
# 2756 4 63.5 4247.7 4+[E1] B(E1)(W.u.) =9.1×10−5
# 5369 4 0.52 1633.674 2+[M2] B(M2)(W.u.) =1.5×10−28
# 7156.3 3−1369 3 405 5787.7 1−[E2] B(E2)(W.u.) =508
# 2908.4 12 605 4247.7 4+[E1] B(E1)(W.u.) =7.9×10−59
# 7191 0+5556 3 100 1633.674 2+[E2] B(E2)(W.u.) =0.31 6
# 7190 3 0.0 0+[E0]
# 7421.9 2+3173.9 17≤7.6 4247.7 4+Iγ: author quotes Iγ/Σ(Iγ)≤7.6%.
# 5787.3 12≥89.2 1633.674 2+[M1+E2]+8.4+15−10 B(M1)(W.u.)=1.0×10−43;
# B(E2)(W.u.)=1.72
# Iγ: author quotes Iγ/Σ(Iγ)≥90.6% 14.
# 7420.4 12≤10.8 0.0 0+Iγ: author quotes Iγ/Σ(Iγ)≤9.4% 14.
# 7833.4 2+3585.4 19<2 4247.7 4+
# 6198.7 15 171 1633.674 2+[M1] B(M1)(W.u.) =2.3×10−33
# 7831.8 15 831 0.0 0+[E2] B(E2)(W.u.) =0.73 9
# 8453 5−2832 5 100 5621.4 3−[E2] B(E2)(W.u.) =276
# 8708 1−7073 7 138 1633.674 2+[E1] B(E1)(W.u.) =5×10−53
# 8706 7 878 0.0 0+[E1] B(E1)(W.u.) =1.9×10−45
# 8777.6 6+4529.3 25 100 4247.7 4+[E2] B(E2)(W.u.) =203
# 9031 4+4782 7<2 4247.7 4+
# 7396 7 100 1633.674 2+[E2] B(E2)(W.u.) =5.87
# 9116 3−3495 4 174 5621.4 3−[M1] B(M1)(W.u.) =4.9×10−312
# 4149 3 335 4966.51 2−[M1] B(M1)(W.u.) =5.8×10−311
# 7480 3 505 1633.674 2+[E1] B(E1)(W.u.) =6.2×10−510
# 9318 (2−) 7682.7 20 100 1633.674 2+
# 9487 2+7848 3 100 1633.674 2+[M1] B(M1)(W.u.) =2.5×10−210
# Iγ: authors report Iγ/Σ(Iγ)=(100)%.
# 9481 3 0.0 0+
# 9873 3+2451 5≈3 7421.9 2+
# 4252 5≈7 5621.4 3−
# 4905 4≤5 4966.51 2−
# 5624 5 123 4247.7 4+
# 8237 4 78 1633.674 2+
# 9870 4<0.5 0.0 0+
# 9935 (1+) 4967 12 225 4966.51 2−
# 8299 12 785 1633.674 2+
# 9990 4+8354 8 100 1633.674 2+[E2] B(E2)(W.u.) =8.337
# Iγ: authors report Iγ/Σ(Iγ)=(100)%.
# 9987 8 0.0 0+
# 10273.2 2+2440.4 33 0.22 6 7833.4 2+[M1] B(M1)(W.u.) =2.6×10−27
# 2852 4 6.94 7421.9 2+[M1] B(M1)(W.u.) =0.64 8
# 4652 4 2.12 5621.4 3−[E1] B(E1)(W.u.) =1.9×10−33
# 5306 3 1.31 4966.51 2−[E1] B(E1)(W.u.) =8.0×10−411
# 8638 3 88.9 5 1633.674 2+[M1] B(M1)(W.u.) =0.30 3
# 10271 3 0.65 14 0.0 0+[E2] B(E2)(W.u.) =9.5×10−226
# 10609 6−2156 8 4.512 8453 5−[M1] B(M1)(W.u.) =6.1×10−328
# 3605 8 95.5 12 7004.0 4−[E2] B(E2)(W.u.) =176
# 10694 4−,3+5726 6 754 4966.51 2−
# 6445 6 254 4247.7 4+
# 10884 3+6635 4 235 4247.7 4+
# 9
# 24Mg12.pdf
# ================================================================================
# ================================================================================
# 24
# 12Mg12-21 From ENSDF24
# 12Mg12-21Adopted Levels ,Gammas (continued)
# γ(24Mg) (continued)
# Ei(level) JπiEγ IγbEf Jπ
# fMult.dαeComments
# α(IPF)=0.001473 21
# Iγ: weighted average of 7.4 19from24Alεdecay (2.053 s), 9 4from
# (α,γ), and 6.9 14from (p,γ).
# 7616.41 3−6246.89†11 1003 1368.667 2+[E1] B(E1)(W.u.) =2.06×10−6+37−28
# 7615.2†9 383 0 0+[E3] B(E3)(W.u.) =5.6+11−8
# Iγ: Unweighted average of 41.5 28from24Alεdecay (2.053 s), 41.4 86
# from (α,γ), and 31.9 28from (p,γ).
# 7747.7 1+3509.1a12.9 9 4238.35 2+
# 6378.1a1003 1368.667 2+
# 7746.4a393 0 0+
# 7812.4 (4−,5+) 1800#123 6010.34 4+
# 2577.4†8 100c5 5235.16 3+Eγ: Other: 2580 (16O,α),(16O,αγ).
# 3690#517 4122.853 4+Iγ: Weighted average of 59 9from (16O,α), 32 9from (α,γ), and 55 5
# from (p,γ).
# 8113.2 6+3990.0‡100 4122.853 4+[E2] 1.17×10−3B(E2)(W.u.)=38+18−10
# α(K)=1.449×10−621;α(L)=9.30×10−813;α(M)=3.45×10−95
# α(IPF)=0.001166 17
# 8358.1 3−2347.7a224 6010.34 4+[E1] 8.77×10−4B(E1)(W.u.)=1.34×10−4+30−27
# α(K)=2.14×10−63;α(L)=1.375×10−720;α(M)=5.10×10−98
# α(IPF)=0.000875 13
# Iγ: From (p,γ). Others: 13 11(α,γ), 52 10from (12C,γ).
# 3122.7a334 5235.16 3+[E1] B(E1)(W.u.) =8.6×10−5+16−13
# Iγ: From (p,γ). Others: 35 11(α,γ), 75 17from (12C,γ).
# 6988.3‡1007 1368.667 2+[E1] B(E1)(W.u.) =2.31×10−5+35−28
# Iγ: weighted average of 100 7from (12C,γ), 100 11from (α,γ), and 100 8
# from (p,γ).
# 8356.5a8.610 0 0+[E3] B(E3)(W.u.) =10.4+20−17
# Iγ: deduced from B(E3) in (e,e′) (1974Jo10 ) and adopted level half-life.
# 8438.4 1−7068.6a2513 1368.667 2+[E1] B(E1)(W.u.) =5.1×10−5+28−22
# 8436.8‡10013 0 0+(E1) B(E1)(W.u.) =1.20×10−4+37−24
# Mult.: D fromγ(θ) (1969Ca18−(α,α′γ) and∆π=yes from levels scheme.
# 8439.29 4+822.0†6 0.05†27616.41 3−[E1] B(E1)(W.u.) =0.00015+13−7
# 1090.67†10 0.32†27348.60 2+[E2] B(E2)(W.u.) =59+43−19
# B(E2)(W.u.)=59+43−19upper bound exceeds RUL =100.
# 2428.97†15 1.79†46010.34 4+
# 3203.88†8 7.21 16 5235.16 3+Iγ: Weighted average of 7.13 16from24Alεdecay (2.053 s) and 7.49 31
# from (p,γ).
# 4200.54†13 9.55 4238.35 2+[E2] 1.24×10−3B(E2)(W.u.)=2.1+15−6
# α(K)=1.347×10−619;α(L)=8.64×10−812;α(M)=3.20×10−95
# 21
# 24Mg12.pdf
# ================================================================================
# ================================================================================
# 24
# 12Mg12-24 From ENSDF24
# 12Mg12-24Adopted Levels ,Gammas (continued)
# γ(24Mg) (continued)
# Ei(level) JπiEγ IγbEf Jπ
# fMult.dαeComments
# 10027.97 5−5904.2‡10010 4122.853 4+[E1] 0.00227 B(E1)(W.u.) =2.6×10−5+11−6
# α(K)=6.95×10−710;α(L)=4.46×10−87;α(M)=1.652×10−924
# α(IPF)=0.00227 4
# 8657.5a6112 1368.667 2+[E3] B(E3)(W.u.) =39+18−11
# 10059.1 (1,2)+5820.0a164 4238.35 2+
# 8688.6&25 1004 1368.667 2+
# 10110.9 (0+) 8740.5a100 1368.667 2+
# 10333.6 3−6094.4a6111 4238.35 2+
# 8963@10011 1368.667 2+
# 10360.7 2+3927.9a1.24 6432.2 0+[E2] 1.15×10−3B(E2)(W.u.)=1.0+6−4
# α(K)=1.482×10−621;α(L)=9.51×10−814;α(M)=3.53×10−95
# α(IPF)=0.001144 16
# 5124.9a3.07 5235.16 3+
# 8990.2‡1004 1368.667 2+
# 10358.3a724 0 0+[E2] B(E2)(W.u.) =0.47+20−11
# 10575.93 (4)+1059.78†8 100†6 9516.18 4+
# 1274.71†10 37.2†21 9301.07 (4+)
# 2136.58†15 59†3 8439.29 4+
# 5340.3†4 40†5 5235.16 3+
# 10581.26 (2+,3+,4+) 4570.4a20.6 8 6010.34 4+
# 5345.4a53.4 15 5235.16 3+
# 6342.0a1003 4238.35 2+
# 6457.4a37.6 13 4122.853 4+
# 9210.6a46.1 15 1368.667 2+
# 10659.8 (1,2+) 9289.2a4311 1368.667 2+
# 10657.3a10011 0 0+
# 10660.17 (3+,4+) 5424.2a123 5235.16 3+
# 6536.3a3513 4122.853 4+
# 9289.5a10013 1368.667 2+
# 10679.7 0+3124a0.6c4 7555.3 1−
# 3331a2.4c4 7348.60 2+
# 6440a14.7c12 4238.35 2+
# 9309a100c3 1368.667 2+
# 10712.2 1+10709.6a100 0 0+
# 10731.1 2+5495.2a103 5235.16 3+
# 6491.8a273 4238.35 2+(M1) B(M1)(W.u.) =0.0023+16−7
# Mult.: D from (γ,θ) in (α,γ);∆π=yes from level scheme.
# 9360.5a1004 1368.667 2+
# 10820.8 3+,4+9450.1†4 100 1368.667 2+
# 10917.2 2+4485a0.85c21 6432.2 0+[E2] 1.34×10−3B(E2)(W.u.)=0.38+11−10
# 24
# 28Si14.pdf
# ================================================================================
# ================================================================================
# Continued on next page (footnotes at end of table)28
# 14Si14-11 From ENSDF28
# 14Si14-11
# Adopted Levels ,Gammas (continued)
# 28Si Levels (continued)
# E(level)†Jπ‡XREF
# 15494 10 (0 to 6)−L
# 15914.8 10 (6+) J
# †From (p,γ), except otherwise noted.
# ‡From L values in (d,n), (p,d), and (3He,d), andγ-ray transitions, except otherwise noted. Additional argu ments are presented as
# comments and footnotes. For resonance states (above 11780 k eV), spin/parity assignments are based on available data from
# (p,γ):resonance strength, (e,e′), (p,p′), (α,γ) studies, along with the L values from (3He,d).
# #Fromγ-ray decay.
# @From (p,γ), based onγ(θ) measurements.
# &From (p,γ), based on theγ-ray angular distribution, linear polarization, and trans ition rates.
# aFromγ-ray decay andγ-ray feeding.
# bFrom (α,γ), based onγ-ray angular distribution measurements.
# cFrom (α,nγ), based on n-γangular correlation and mean lifetime.
# dFrom spectroscopic strength in (p, γ): Resonance and/or based on theα0orα1decay.
# eFrom 1984Ne03 and1984Ne04 in (p,p): Resonance.
# fT1/2orΓ.Γfrom 1984Ne03 or1984Ne04 , except otherwise noted. For levels at 14535 keV and above −Γquoted from
# 1995Br16 .
# gΓfrom 1978Ma23 .
# hΓ−from 1995Br16 .
# iΓ−From Table 28.17 in 1990En08 .
# jBand(A): Oblate band based on g.s.
# kBand(B): Kπ=3+band.
# lBand(C): Prolate band based on 0+.
# mBand(D): Vibrational band.
# nBand(E): SD band based on 2+.
# γ(28Si)
# Ei(level) Jπ
# iEγ†Iγ@Ef Jπ
# fMult.bδ Comments
# 1779.030 2+1778.969‡11 100 0.0 0+E2 B(E2)(W.u.) =13.2 5
# 4617.86 4+2838.29‡15 100 1779.030 2+(E2) B(E2)(W.u.) =16.4 18
# 4979.92 0+3200.7‡5 100 1779.030 2+E2 B(E2)(W.u.) =9.56
# 6276.20 3+1658.2 13.4 4 4617.86 4+
# 4496.92‡25 100.0 4 1779.030 2+(M1+E2)−0.14 2B(M1)(W.u.)=0.000269 21;
# B(E2)(W.u.)=0.0013 4
# δ: From 1974Da15 . Other:−0.12 5
# (1963Br15 ).
# 6690.74 0+4910.8 5 100 1779.030 2+E2 B(E2)(W.u.) =0.267 19
# 6878.79 3−2260.7 3.9 6 4617.86 4+(E1) B(E1)(W.u.) =9.1×10−717
# 5098.8 39.0 15 1779.030 2+
# 6877.0 100.0 16 0.0 0+[E3] B(E3)(W.u.) =13.2 15
# 6887.65 4+2269.6 1.31 9 4617.86 4+
# 5107.6 100.00 9 1779.030 2+(E2) B(E2)(W.u.) =0.96 6
# 7380.59 2+2400.5 0.47 16 4979.92 0+E2 B(E2)(W.u.) =0.85
# 5600.4 100.0 8 1779.030 2+
# 7378.5 57.3 8 0.0 0+E2 B(E2)(W.u.) =0.37 15
# 7416.26 2+5636.0 6.4 22 1779.030 2+
# 11
# 28Si14.pdf
# ================================================================================
# ================================================================================
# Continued on next page (footnotes at end of table)28
# 14Si14-12 From ENSDF28
# 14Si14-12
# Adopted Levels ,Gammas (continued)
# γ(28Si) (continued)
# Ei(level) Jπ
# iEγ†Iγ@Ef Jπ
# fMult.bδ Comments
# 7416.26 2+7414.2 100.0 22 0.0 0+E2 B(E2)(W.u.) =0.162 18
# 7799.01 3+911.3 0.21 3 6887.65 4+
# 1522.7 49.5 17 6276.20 3+
# 3180.8 2.00 13 4617.86 4+
# 6018.6 100.0 17 1779.030 2+
# 7933.45 2+1657.1 2.9 15 6276.20 3+
# 2953.2 4.81 24 4979.92 0+E2 B(E2)(W.u.) =1.84
# 3315.2 5.65 24 4617.86 4+(E2) B(E2)(W.u.) =1.20 23
# 6153.0 6.61 24 1779.030 2+
# 7931.0 100.0 18 0.0 0+E2 B(E2)(W.u.) =0.27 5
# 8258.74 2(+)3278.4 24.3 15 4979.92 0+E2 B(E2)(W.u.) =5.011
# 3640.4 5.7 15 4617.86 4+(E2) B(E2)(W.u.) =0.70 24
# 6478.1 100 3 1779.030 2+
# 8256.1 12.9 22 0.0 0+E2 B(E2)(W.u.) =0.026 7
# 8328.38 1+2052.0 28 4 6276.20 3+
# 6547.7 45 9 1779.030 2+
# 8325.7 100 9 0.0 0+M1 B(M1)(W.u.) =6.E−54
# 8413.33 4−1534.5 100.0 8 6878.79 3−(M1+E2)−0.17 1 B(M1)(W.u.)=0.0146 25;
# B(E2)(W.u.)=0.91 19
# δ: From 1974Da15 . Other:−0.18 4
# (1981Gl05 ).
# 3794.9 3.50 25 4617.86 4+
# 6632.6 21.3 8 1779.030 2+(M2+E3)+2.52 B(M2)(W.u.)=0.019 5; B(E3)(W.u.)=214
# δ: From 1974Da15 .
# 8543.56 6+3925.1 3100 4617.86 4+[E2] B(E2)(W.u.) =10.6 10
# 8588.71 3+789.7 0.59 10 7799.01 3+[M1] B(M1)(W.u.) =0.021 6
# 1700.9 0.34 23 6887.65 4+
# 2312.3 7.85 23 6276.20 3+
# 3970.3 4.89 23 4617.86 4+
# 6807.9 100.0 5 1779.030 2+
# 8904.8 1−7123.8 100 6 1779.030 2+[E1] B(E1)(W.u.) =0.00013 4
# 8901.8 89 6 0.0 0+[E1] B(E1)(W.u.) =6.1×10−516
# 8945.20 5+2057.4 64 4 6887.65 4+(M1+E2)>25 B(M1)(W.u.) <3.1×10−5; B(E2)(W.u.)>18
# δ: From 1986Gl05 .
# 4326.6 100 4 4617.86 4+(M1+E2)+7+7−2B(M1)(W.u.)=6.E−5+12−6;
# B(E2)(W.u.)=0.76 10
# δ: From 1995Br17 .
# 8953.3 (0+,1,2) 7172.3 100 1779.030 2+
# 9164.68 (4+) 1748.3 9.8 11 7416.26 2+[E2] B(E2)(W.u.) =11.1 18
# 1784.0 29.3 22 7380.59 2+[E2] B(E2)(W.u.) =304
# 2276.8 6.3 7 6887.65 4+
# 2285.7 4.1 7 6878.79 3−[E1] B(E1)(W.u.) =4.2×10−59
# 4546.0 67.0 9 4617.86 4+
# 7383.6 100 5 1779.030 2+[E2] B(E2)(W.u.) =0.084 11
# 9315.92 3+727.2 0.8 3 8588.71 3+
# 1516.8 2.4 6 7799.01 3+
# 3039.4 37 3 6276.20 3+(M1+E2)−0.22 B(M1)(W.u.)=0.13 6; B(E2)(W.u.)=3
# +6−3
# δ: From 1978Da08 .
# 7534.7 100 3 1779.030 2+(M1+E2)+0.01 1 B(M1)(W.u.)=0.024 10;
# B(E2)(W.u.)=0.00022+45−22
# δ: From 1978Ma23 . Other:+0.08 6
# (1978Da08 ).
# 9381.55 2+1122.7 0.60 18 8258.74 2(+)(M1) B(M1)(W.u.) =0.08 3
# 1448.0 3.14 23 7933.45 2+(M1) B(M1)(W.u.) =0.18 6
# 1965.1 0.12 7 7416.26 2+
# 12
# 28Si14.pdf
# ================================================================================
# ================================================================================
# Continued on next page (footnotes at end of table)28
# 14Si14-13 From ENSDF28
# 14Si14-13
# Adopted Levels ,Gammas (continued)
# γ(28Si) (continued)
# Ei(level) Jπ
# iEγ†Iγ@Ef Jπ
# fMult.bδ Comments
# 9381.55 2+3105.0 4.48 23 6276.20 3+(M1) B(M1)(W.u.) =0.027 8
# 7600.3 100.0 13 1779.030 2+(M1+E2)+0.09 5B(M1)(W.u.)=0.040 11; B(E2)(W.u.)=0.03
# +4−3
# δ: From 1978Ma23 .
# 9378.2 3.7 4 0.0 0+(E2) B(E2)(W.u.) =0.046 14
# 9417.17 4+1483.6 27 4 7933.45 2+(E2) B(E2)(W.u.) =235
# 1618.1 100 6 7799.01 3+
# 2000.8 13 9 7416.26 2+
# 2036.4 1.2 2 7380.59 2+(E2) B(E2)(W.u.) =0.21 5
# 2529.3 18.8 6 6887.65 4+
# 3140.6 3.1 2 6276.20 3+
# 4798.4 36.3 14 4617.86 4+
# 7635.9 33.3 10 1779.030 2+(E2) B(E2)(W.u.) =0.0079 13
# 9479.49 (2+) 2063.1 0.58 7 7416.26 2+
# 2098.7 0.71 24 7380.59 2+
# 4498.8 5.3 18 4979.92 0+(E2) B(E2)(W.u.) =0.46 22
# 4860.7 7.5 4 4617.86 4+(E2) B(E2)(W.u.) =0.44 15
# 7698.2 3.04 15 1779.030 2+
# 9476.1 100.0 24 0.0 0+(E2) B(E2)(W.u.) =0.21 7
# 9496.04 (1+) 7714.7 18 5 1779.030 2+
# 9492.6 100 5 0.0 0+(M1) B(M1)(W.u.) =0.0044 18
# 9702.34 (5−) 1288.9 100 5 8413.33 4−(M1+E2)<+2.0 B(M1)(W.u.) >0.00017; B(E2)(W.u.) <3.6
# δ: From 1981Gl05 .
# 2814.4 15.6 23 6887.65 4+
# 2823.2 51.1 23 6878.79 3−(E2) B(E2)(W.u.) =0.036 10
# 5083.5 33.3 23 4617.86 4+
# 7920.9 22.2 23 1779.030 2+(E3) B(E3)(W.u.) =0.33 9
# 9764.52 (3−) 2885.4 0.57 16 6878.79 3−
# 3487.9 2.6 3 6276.20 3+(E1) B(E1)(W.u.) >0.00022
# 7983.1 100.0 3 1779.030 2+(E1) B(E1)(W.u.) >0.00070
# 9795.95 (2+) 3105#6690.74 0+Iγ:γ-ray branching not available.
# 4815.1 7.2 4 4979.92 0+
# 8014.5 78 2 1779.030 2+
# 9792.3 100 2 0.0 0+(E2)
# 9929.2 1−9925.4 100 0.0 0+(E1)
# 10181.60 (3−) 1016.9 31.0 14 9164.68 (4+) (E1) B(E1)(W.u.) =0.022 7
# 3904.8 10 3 6276.20 3+(E1) B(E1)(W.u.) =0.00012 6
# 5562.6 100 3 4617.86 4+(E1) B(E1)(W.u.) =0.00043 13
# 10189.59 (5−,3−) 3310.4 100 6878.79 3−
# 10209.01 (3+) 2792.5 4.7 20 7416.26 2+
# 5590.0 29 7 4617.86 4+(E2) B(E2)(W.u.) =0.45 18
# 8427.3 100 7 1779.030 2+
# 10272.3 0+1943.8 70 3 8328.38 1+M1 B(M1)(W.u.) >0.029
# 8490.5 100 3 1779.030 2+E2 B(E2)(W.u.) >0.036
# 10310.92 (4+) 4034.1 20 6 6276.20 3+
# 5691.8 100 10 4617.86 4+
# 8529.1 80 12 1779.030 2+
# 10376.24 (3+,4+) 1787.4 75 4 8588.71 3+
# 3488.1 21 4 6887.65 4+
# 4099.4 100 11 6276.20 3+
# 5757.1 79 7 4617.86 4+
# 8594.4 70 5 1779.030 2+
# 10418.25 (5+) 2619.0 6.2 11 7799.01 3+(E2) B(E2)(W.u.) =2.37
# 3530.1 11.4 7 6887.65 4+
# 4141.4 100 3 6276.20 3+(E2) B(E2)(W.u.) =3.79
# 13
# 32S16.pdf
# ================================================================================
# ================================================================================
# Continued on next page (footnotes at end of table)32
# 16S16-2 From ENSDF - Evaluated August 201132
# 16S16-2
# H28Si(18O,14C)T32S(p,p′),(pol p,p′)AE32S(d,d′),(pol d,d′)
# I29Si(α,nγ)U32S(p,p′γ)AF32S(α,α′)
# J30Si(16O,14C)V33S(p,d) AG Coulomb excitation
# K31P(p,γ) W33S(3He,α)
# L31P(p,p′)X34S(p,t)
# E(level)†JπT1/2 XREF Comments
# 0 0+stableA C FGHIJK NOP STUVWXYZ XREF: Others:AA,AC,AD,AE,AF,AG
# <r2>1/2=3.2611 fm 18(2008 update of 2004An14 evaluation
# by I. Angeli: available at http: //cdfe.sinp.msu.ru.).
# Jπ: measurements by optical spectroscopy
# (1936Ol01 ,1931Na01 ).
# 2230.57 15 2+169 fs 11A C FGHI K NOPQ STUVWX Z XREF: Others:AC,AD,AE,AF,AG
# µ=+0.94 18(1979Za01 ,1989Ra17 )
# Q=−0.154 20(1981Sp07 ,1989Ra17 )
# E(level): from32S(γ,γ′).
# Jπ: E2γto 0+.
# T1/2: weighted average of 175 fs 28(1998Ka31 ), 135 fs 49
# (1974Ch09 ), 128 fs 52(1972Co12 ), 243 fs 42(1971In02 ),
# 180 fs 55(1969Th03 ), 121 fs 21(1971Re15 ), 147 fs 24
# (2002Ba28 ), 228 fs 55(1964Ma01 ), 250 fs 27(1964Lo08 ),
# 240 fs 40(1971In02 ), 164 fs 11(1971Ga04 ), 160 fs 40
# (1980Ba40 ).2001Ra27 evaluation gives 171 fs 8from a set
# of 22 quoted measurements from 1956 to 1980 using DSA,
# Coul. ex., (γ,γ′) and (e,e′).
# µ: transient-ﬁelds ( 1979Za01 ). See also 2005St24 compilation.
# Q: reorientation in Coulomb ex. (recalculated by 1981Sp07 ).
# Measurements:−0.160 22or−0.133 22(1982Ve09 ),−0.18 4
# or−0.15 4(1981Da08 ),−0.12 5(1980Ba40 ). See also
# 2005St24 compilation.
# 3778.4 10 0+0.89 ps 9A C EFG I K NO Q STUVWX XREF: Others:AD,AF
# Jπ: from34S(p,t) L=0 angular distribution.
# T1/2: from28Si(6Li,pnγ).
# 4281.8 3 2+42 fs 4A C E HI K NOPq STUVWX XREF: Others:AD,AE,AF
# E(level): from32S(γ,γ′).
# Jπ: from32S(p,t) L=2,31P(p,γ)γγ(θ),32S(p,p′γ)γγ(θ).
# T1/2: from weighted average of all available data.
# Additional information 2 .
# 4459.1 8 4+124 fs 27C FGHI K NO STUVWX XREF: Others:AD,AE,AF
# µ=+1.66(1988Si14 ,1989Ra17 )
# E(level): from31P(p,γ).
# Jπ: from31P(p,γ)γγ(θ),32S(p,p′) Ay(θ),32S(p,p′γ),
# γγ(θ) and L=4 in34S(p,t).
# T1/2: from32S(α,α′).
# µ: transient-ﬁelds ( 1988Si14 ). See also 2005St24 compilation.
# 4695.3 4 1+286 fs 74A C I K NO TUVWX XREF: Others:AD
# E(level): from31P(p,γ).
# Jπ: from32S(p,p′γ)γγ(θ); L(p,d)=0+2 from 3/2+.
# T1/2: from29Si(α,nγ).
# 5006.2 3 3−0.52 ps 3C FGHI K NO Q STUVWX XREF: Others:AC,AD,AE
# B(E3)↑=0.0127 20(2002Ki06 )
# E(level): from31P(p,γ).
# Jπ: from31P(p,γ)γ(θ) and polarization,28Si(α,γ)γγ(θ),
# 32S(p,p′) angular distributions and L =3 in31P(d,n) from
# 1/2+and33S(p,d) from 3/2+.
# T1/2: from weighted average of all available data.
# Additional information 3 .
# 5412.6 10 3+148 fs 19C EF I K NO UVWX E(level): from31P(p,γ).
# 2
# 32S16.pdf
# ================================================================================
# ================================================================================
# 32
# 16S16-18 From ENSDF32
# 16S16-18Adopted Levels ,Gammas (continued)
# γ(32S)
# Ei(level) JπiEγ†Iγ†Ef Jπ
# fMult.†δ†I(γ+ce) Comments
# 2230.57 2+2230.49 15 100 0 0+E2 E γ: from32S(γ,γ′).
# 3778.4 0+1548.8 15 100 2230.57 2+[E2] B(E2)(W.u.) =11.8 12
# 3778 0 0+[E0] 0.035 6q2K(E0/E2)=0.044 8, X(E0/E2)=0.047 9,ρ2=0.019 5(2005Ki02
# evaluation).
# I(γ+ce): from31P(3He,d) ( 1975Ad02 ).γintensity<10.
# 4281.8 2+503.7<0.4 3778.4 0+
# 2052.6 15 14.9 6 2230.57 2+E2+M1−2616 B(M1)(W.u.)=1.2×10−5+15−12; B(E2)(W.u.)=7.99
# Mult.,δ: from31P(p,p′γ).
# 4281.5 3 100.0 6 0 0+Eγ: from32S(γ,γ′).
# 4459.1 4+681.4<0.3 3778.4 0+
# 2229.4 12 100.0 2230.57 2+E2 B(E2)(W.u.) =143
# 4458.4<1.0 0 0+
# 4695.3 1+414.1<0.98 4281.8 2+
# 917.8<0.65 3778.4 0+
# 2466.0 15 100.0 17 2230.57 2+M1(+E2)−0.08 10 B(M1)(W.u.)=(0.0031 8); B(E2)(W.u.)=(0.014+35−14)
# Mult.,δ: note31P(p,p′γ) makes a case for a stronger E2 component.
# 4694.0 25 63.9 17 0 0+[M1] B(M1)(W.u.) =0.00029 8
# 5006.2 3−724.8<0.1 4281.8 2+
# 1228.4<0.4 3778.4 0+
# 2776.2 12 100.0 5 2230.57 2+E1(+M2) 0.00 5 B(E1)(W.u.)=(5.8×10−54)
# 5005.4 3.5 5 0 0+E3 B(E3)(W.u.) =163
# 5412.6 3+406.2<2 5006.2 3−
# 716.9<1 4695.3 1+
# 953.3<1 4459.1 4+
# 1131.0<6 4281.8 2+
# 1634.6<20 3778.4 0+
# 3181.8 100 2230.57 2+E2+M1+7.619 B(M1)(W.u.)=7.E−54; B(E2)(W.u.)=1.63
# 5411.4<5 0 0+
# 5548.5 2+541.2<0.7 5006.2 3−
# 851.9<1.6 4695.3 1+
# 1088.3<3.3 4459.1 4+
# 1265.9<1.6 4281.8 2+
# 1769.6<1.6 3778.4 0+
# 3318.5 100.0 25 2230.57 2+E2+M1−5.221 B(M1)(W.u.)=0.00022 18; B(E2)(W.u.)=2.33
# 5546.4 66.7 25 0 0+
# 5796.8 1−791.3<1 5006.2 3−
# 1102.0<1 4695.3 1+
# 1338.3<1.5 4459.1 4+
# 1516.0<1 4281.8 2+
# 2019.7<1.5 3778.4 0+
# 3566.8<5 2230.57 2+
# 18
# 32S16.pdf
# ================================================================================
# ================================================================================
# 32
# 16S16-19 From ENSDF32
# 16S16-19Adopted Levels ,Gammas (continued)
# γ(32S) (continued)
# Ei(level) JπiEγ†Iγ†Ef Jπ
# fMult.†δ†Comments
# 5796.8 1−5796.3 3 100.0 0 0+Eγ: from32S(γ,γ′).
# 6222.9 2−811.3<0.2 5412.6 3+
# 1217.5 3 2 5006.2 3−
# 1528.1<0.5 4695.3 1+
# 1764.5<0.6 4459.1 4+
# 1942.2<1.5 4281.8 2+
# 2445.8<0.8 3778.4 0+
# 3993.0 20 100.0 21 2230.57 2+E1+M2−0.07 3B(E1)(W.u.)=0.00015 3; B(M2)(W.u.)=0.21 19
# 6222.4<1.5 0 0+
# 6411 4+4179 100.0 2230.57 2+
# 6621.7 4−1209.1<1.2 5412.6 3+E1 B(E1)(W.u.) =5.E−65
# 1615.2 100.0 14 5006.2 3−E2+M1 2.9 8 B(M1)(W.u.)=0.0011 6; B(E2)(W.u.)=153
# 1925.9<0.4 4695.3 1+
# 2162.2 32.9 10 4459.1 4+E1(+M2)−0.06 2B(E1)(W.u.)=(4.4×10−58); B(M2)(W.u.)=(0.15 11)
# 2339.9<0.27 4281.8 2+
# 2843.5<0.82 3778.4 0+
# 4390.6 4.1 5 2230.57 2+M2+E3−0.41 8B(M2)(W.u.)=0.13 3; B(E3)(W.u.)=83
# 6620.0<0.41 0 0+
# 6666.1 2+1253.3<2 5412.6 3+
# 1659.5<8 5006.2 3−
# 1970.2 29 4 4695.3 1+
# 2206.5<6 4459.1 4+
# 2384.2<14 4281.8 2+
# 2887.9 20 10011 3778.4 0+
# 4434.8 76 9 2230.57 2+
# 6664.3<6 0 0+
# 6761.6 5−1349.1<4 5412.6 3+
# 1755.3 100 4 5006.2 3−[E2] B(E2)(W.u.) =143
# Additional information 5 .
# 2066.0<11 4695.3 1+
# 2302.3 32 14 4459.1 4+E1+M2−0.6 B(E1)(W.u.) =3.3×10−516; B(M2)(W.u.)=105
# Additional information 6 .
# 2480.0<4 4281.8 2+
# 2983.6<5 3778.4 0+
# 4530.6<9 2230.57 2+
# 6760.1 2.7 14 0 0+
# 6851.5 4+1439.9 13 7 5412.6 3+
# 1846.1<16.2 5006.2 3−
# 2156.7<6 4695.3 1+
# 2393.1 13 7 4459.1 4+E2 Additional information 7 .
# Mult.: from29Si(α,nγ).
# 2570.8 100 13 4281.8 2+E2 B(E2)(W.u.) =83
# 19
# 34S16.pdf
# ================================================================================
# ================================================================================
# Continued on next page (footnotes at end of table)34
# 16S18-2 From ENSDF34
# 16S18-2
# Adopted Levels ,Gammas (continued)
# 34S Levels (continued)
# E(level)†Jπ‡T1/2 XREF Comments
# T1/2: mean lifetimeτin fs, from31P(α,pγ): 440 50
# (1970Gr11 ), 400 32(1970Ra17 ), 400 40(1974Gr06 ),
# 46095(1970Br18 ), 467 90(1970Cu02 ); from
# 32S(t,pγ): 490 30(1977He12 ); from34S(e,e′): 486 17
# (1985Wo06 ); from34S(α,α′): 442 25(1980Ba40 );
# from28Si(34S,34S′): 462 26(1977Sc36 ). Weighted
# average (external uncertainty) τ: 459 fs 11. Others
# T1/2: 350 fs 60(1969Gr03 , from31P(α,pγ)); 380 fs
# 60(1974Ol02 , from206Pb(34S,34S′γ)); 307 fs 17
# (2001Ra27 evaluation, total of 14 measurements are
# listed in this evaluation).
# 3304.212 13 2+136 fs 7CDE GHI K M OPQRSTUVWX B(E2)↑=0.00246 13
# Jπ: E2∆J=2γto 0+, g.s. (24Mg(16O,α2pγ)).
# T1/2: mean lifetimeτin fs, from31P(α,pγ): 218 30
# (1970Gr11 ); 175 25(1970Ra17 ); 190 40(1970Br18 ).
# From31P(α,pγ): 192 13(1977He12 ). From34S(e,e′):
# 21625(1985Wo06 ). Weighted average: 196 10.
# Others (from31P(α,pγ)): 145 20(1974Gr06 ); 144 28
# (1970Cu02 ); 120 30(1969Gr03 ).
# 3916.408 21 0+1.12 ps 9A FGH K M RSTU Jπ: L=0 in32S(t,p).
# T1/2: mean lifetimeτin fs, from31P(α,pγ): 1600 130
# (1970Gr11 ); 1890 500. Weighted average: 1618 126.
# 4074.667 14 1+<17 fsA GH K M Rs U W XREF: s(4094).
# Jπ: D∆J=1γto 0+, g.s. ( 1970Mo09 ,1971Mu03 );
# π=+from L=0 in35Cl(d,3He).
# T1/2: mean lifetimeτin fs, from31P(α,pγ):<33
# (1970Gr11 );<24 (1970Ra17 );≤50 (1974Gr06 ).
# 4114.813 23 2+73 fs 6A C GH K M QRsTU XREF: s(4094).
# Jπ: E2∆J=2γto 0+, g.s. (31P(α,pγ)), or L=2 in
# 32S(t,p).
# T1/2: mean lifetimeτin fs (31P(α,pγ)): 89 20
# (1970Gr11 ); 110 10(1970Ra17 ); 100 15(1974Gr06 ).
# Weighted average: 105 9.
# 4624.404@16 3−84 fs 5D GH JK M QRs U X XREF: s(4655).
# Jπ: L=3 in32S(t,p), and also from34S(p,p′),(pol p,p′).
# T1/2: mean lifetimeτin fs, from31P(α,pγ): 125 20
# (1970Gr11 ); 135 17(1970Ra17 ); 145 50(1971So01 );
# 11510(1974Gr06 ). Weighted average: 121 8.
# Adopted B(E3)=0.008 2(2002Ki06 evaluation).
# 4688.98#5 4+88 fs 4CD GH K M QRsTU WX XREF: s(4655).
# Jπ: E2∆J=2γto 2+, 2127 and test of spin
# hyphotheses (31P(α,pγ)); also J=4 in34S(n,n),(n,n′).
# T1/2: mean lifetimeτin fs, from31P(α,pγ): 132 15
# (1970Gr11 ); 131 13(1970Ra17 ); 110 20(1971So01 );
# 12510(1974Gr06 ); 130 20(1977GrZH ). Weighted
# average: 127 6.
# 4876.839 24 3+40 fs 15CD G K M u w XREF: u(4880)w(4900).
# Jπ: M1+E2∆J=1γto 2+, 3303 and test of spin
# hyphotheses ( 1971Mu03 ).
# T1/2: mean lifetimeτin fs, from31P(α,pγ): 57 22
# (1970Ra17 ). Others:<85 (1970Gr11 ),≤70
# (1974Gr06 ).
# 4882 14 4+R u w XREF: u(4880)w(4900).
# 2
# 34S16.pdf
# ================================================================================
# ================================================================================
# 34
# 16S18-12 From ENSDF34
# 16S18-12Adopted Levels ,Gammas (continued)
# γ(34S)
# Ei(level) JπiEγ†Iγ†Ef Jπ
# fMult.δ Comments
# 2127.564 2+2127.499 20 100 0.0 0+E2 B(E2)(W.u.) =6.24 16
# Mult.: from31P(α,pγ),24Mg(16O,α2pγ).
# 3304.212 2+1176.650 20 100.0 9 2127.564 2+M1+E2−0.16 2 B(M1)(W.u.)=0.052 3; B(E2)(W.u.)=3.810
# Mult.,δ: D+Q∆J=0γ(31P(α,pγ)).
# 3304.031 20 87.2 9 0.0 0+E2 B(E2)(W.u.) =0.75 4
# Mult.: Q∆J=2γ(31P(α,pγ)).
# 3916.408 0+612.16 5 0.33 4 3304.212 2+
# 1788.794 20 10010 2127.564 2+E2 B(E2)(W.u.) =4.27
# Mult.: D,Q∆J=0,1,2γ, D,E2 based on RUL (31P(α,pγ)); D excluded based
# on level scheme.
# 3916.2@<2 0.0 0+[E0] X(E0 /E2)=0.093 15,ρ2(E0)=0.011 3, q2
# K(E0/E2)=0.055 9(2005Ki02
# evaluation).
# Eγ: from∆Elevels.
# Iγ: from31P(α,pγ).
# 4074.667 1+158.3@<0.2 3916.408 0+
# 770.428 20 8.98 3304.212 2+D Mult.: D γbased on RUL.
# 1947.060 20 9410 2127.564 2+M1+E2+1.3+9−32 B(M1)(W.u.)>0.0039; B(E2)(W.u.) >26
# Mult.: D+Q∆J=1γ, M1+E2 based on RUL (31P(α,pγ)).
# δ: from31P(α,pγ).
# 4074.418 20 10010 0.0 0+D Mult.: D ∆J=1γ(31P(α,pγ)).
# 4114.813 2+198.4@<0.35 3916.408 0+
# 810.6@<0.70 3304.212 2+
# 1987.19 3 768 2127.564 2+M1+E2−0.40 5 B(M1)(W.u.)=0.0143 23; B(E2)(W.u.)=2.36
# Mult.: D+Q∆J=0γ, M1+E2 based on RUL (31P(α,pγ)).
# δ: from31P(α,pγ).
# 4114.52 4 10010 0.0 0+E2 B(E2)(W.u.) =0.57 9
# Mult.: Q∆J=2γ, E2 based on RUL (31P(α,pγ)).
# 4624.404 3−509.6@12<4 4114.813 2+Eγ: from∆Elevels.
# Iγ: from31P(α,pγ).
# 549.7@<0.13 4074.667 1+
# 708.0@<0.29 3916.408 0+
# 1320.169 20 10011 3304.212 2+D Mult.: from31P(α,pγ) and24Mg(16O,α2pγ).
# δ:−0.03 5(31P(α,pγ)).
# 2496.726 20 414 2127.564 2+D Mult.: from31P(α,pγ) and24Mg(16O,α2pγ).
# δ:+0.02 4(31P(α,pγ)).
# 4624.2@5 0.55 13 0.0 0+[E3] B(E3)(W.u.) =185
# 4688.98 4+573.4@11<3 4114.813 2+Eγ: from∆Elevels.
# Iγ: from31P(α,pγ).
# 12
# 34S16.pdf
# ================================================================================
# ================================================================================
# 34
# 16S18-15 From ENSDF34
# 16S18-15Adopted Levels ,Gammas (continued)
# γ(34S) (continued)
# Ei(level) JπiEγ†Iγ†Ef Jπ
# fMult.δ Comments
# 5679.927 3−1605.3@<0.4 4074.667 1+
# 1763.5@<0.4 3916.408 0+
# 2375.657 20 1009 3304.212 2+D+Q<−0.4 Mult.: D +Qγ(31P(α,pγ)).
# δ: from31P(α,pγ):<−0.4 or>+2.4.
# 3552.08 4 66.7 7 2127.564 2+D+Q−0.47+7−11 Mult.: D+Qγ(31P(α,pγ)).
# δ: from31P(α,pγ).
# 5679.9@<2.0 0.0 0+
# 5690.7 5−1001.6 5 10010 4688.98 4+E1 B(E1)(W.u.) =9.4×10−613
# Eγ,Iγ: from24Mg(16O,α2pγ).
# Mult.: D(+Q)∆J=1γ, E1 from polarization measurement (31P(α,pγ)).
# 1066.2 5 8310 4624.404 3−E2 B(E2)(W.u.) =0.76 12
# Eγ,Iγ: from24Mg(16O,α2pγ).
# Mult.: Q∆J=2γ, E2 from polarization measurement (31P(α,pγ)).
# 3562.7 6 2.912 2127.564 2+[E3] B(E3)(W.u.) =1.05
# Eγ,Iγ: from24Mg(16O,α2pγ).
# 5755.875 1−433.4@<0.3 5322.51 2(−)
# 527.7@<0.3 5228.175 0+
# 866.1@<0.4 4889.756 2+
# 879.0@<0.4 4876.839 3+
# 1066.9@<0.5 4688.98 4+
# 1131.5@<0.5 4624.404 3−
# 1640.7 10 1.010 4114.813 2+
# 1681.2@<0.5 4074.667 1+
# 1839.5@<4.0 3916.408 0+
# 2451.557 20 303 3304.212 2+
# 3628.10 4 1009 2127.564 2+
# 5755.5 5 2.95 0.0 0+
# 5847.53 0+525.0@<0.9 5322.51 2(−)
# 619.4@<0.9 5228.175 0+
# 957.8@<1.5 4889.756 2+
# 970.7@<1.5 4876.839 3+
# 1158.6@<2.7 4688.98 4+
# 1223.1@<2.1 4624.404 3−
# 1732.7@<7.85 4114.813 2+
# 1772.82 4 14.6 15 4074.667 1+
# 15
# 36Ar18.pdf
# ================================================================================
# ================================================================================
# Continued on next page (footnotes at end of table)36
# 18Ar18-2 From ENSDF36
# 18Ar18-2
# Adopted Levels ,Gammas (continued)
# 36Ar Levels (continued)
# E(level)†Jπ‡T1/2 XREF Comments
# Q: measured by Coulomb excitation
# reorientation ( 1971Na06 ,
# 206Pb(36Ar,36Ar′γ)).
# T1/2: weighted average (in fs) of: 310 31
# (9Be(40Ca,13Cγ)), 341 20(36Ar(e,e′)), 335
# 27(197Au(36Ar,36Ar′γ)), 305 49
# (206Pb(36Ar,36Ar′γ)), 319 78
# (32S(α,γ):res), 319 28(35Cl(p,γ):res);
# other: 450 14(12C(32S,8Be)). 2001Ra27
# evaluation gives adopted τ=463 fs 46or
# T1/2=321 fs 32.
# 4178.32 11 3−2.3 ps 3BC EF IJKLMNOPQRSTUV X B(E3)=0.0111 11(2002Ki06 evaluation), data
# from lifetime and (e,e′).
# 4329.1e7 (0,1,2)+#>485 fs C I KL N P S V XREF: Others:AF
# 4414.40d16 4+#76 fs 10EF I LMN P RST W XREF: Others:AC,AG
# 4440.11 19 2+76 fs 14B I LMN P UVWX Jπ:πfrom 2699.4, M1+E2γfrom 3+, 7140;
# L=4 in40Ca(d,6Li).
# 4951.4e4 2+#<35 fsB F I KL N P V
# 4974.05 18 2−10 ps 3B E MN P RS V
# 5171.13 16 5−88 ps 3EF I KLMNOP S V
# 5194.4 8 (0+,1+,2+,3−) 69 fs 21 KL N P R V
# 5836.0 4 1−6.2 fs 21 KL N P
# 5856.65 19 3−0.31 ps 10 KL N P V
# 5878? 9 (2+) RS V X Jπ: from36Ar(p,p′).
# 5895.92 19 4−0.35 ps 14 MN V
# 6136.5e15 4+#I KLMN V Jπ: E1γfrom 5−, 9927 (35Cl(p,γ):res); E2
# γto 2+, 1970 (24Mg(20Ne,2αγ)).
# 6217.3 3 5−201 fs 35 LMN R V
# 6356.0 6 4+0.31 ps 10 N R V X
# 6611.0 3 2+15 fs 6B N P UV T=1
# Jπ: log ft=3.5 (36Kεdecay).
# 6645.6 15 (2+,3+,4+) N V
# 6724 2 NOT (2)+N P x Jπ: not 1+(35Cl(p,γ):res) and (1,2)+from
# 35Cl(3He,d).
# 6731.0 5 1+,2+B x Jπ: log ft=5.11 from 2+;γto 0+.
# 6835.16 19 4−0.56 ps 17E N P
# 6836.50 18 3−166 fs 42 KL N
# 6866.9 7 (1+,2+) B L N P R V E(level): 6868.5 10(1972Ho40 ), 6865.2 10
# (1974Jo02 ).
# Jπ: (1,2+) from35Cl(p,γ):res;π=−from
# L=(0) in35Cl(3He,d).
# 7136.5 9 (1−,2+) 9 fs 3 N P
# 7139.6 4 3+69 fs 35B N
# 7178.9 4 (1,2)+B N P V Jπ: (1,2+) from35Cl(p,γ):res;π=+from
# L=0 in35Cl(3He,d).
# 7247.4 6 (1,2,3)−<21 fs N P Jπ: 0+,1,2,3,4+fromγto 2+, 1970; (1,2,3)−
# fromπ=−(35Cl(3He,d)).
# 7258.6 8 3−<14 fs N R V
# 7336.6 6 3+10 fs 5B N P V T=1
# 7353.9 3 6−125 fs 28 I MN V
# 7432.3 7 1+1.5 fs 3 L N PQ V Jπ,T1/2: from36Ar(e,e′).
# 7488 16 (2−) QR V E(level): weighted average of values from
# datasets.
# 2
# 36Ar18.pdf
# ================================================================================
# ================================================================================
# 36
# 18Ar18-9 From ENSDF36
# 18Ar18-9Adopted Levels ,Gammas (continued)
# γ(36Ar)
# Ei(level) JπiEγ†Iγ†Ef Jπ
# fMult.‡δ‡Comments
# 1970.38 2+1970.3 100 0.0 0+E2 B(E2)(W.u.) =8.25
# 4178.32 3−2207.9 100 1 1970.38 2+E1 B(E1)(W.u.) =2.3×10−53
# 4178.1 7.3 10 0.0 0+[E3] B(E3)(W.u.) =20.6 20(2002Ki06 )
# 4329.1 (0,1,2)+2358.6 100 1970.38 2+
# 4328.8<10 0.0 0+
# 4414.40 4+2443.9 100 1970.38 2+E2 B(E2)(W.u.) =12.0 16
# 4414.1<2 0.0 0+
# 4440.11 2+2469.6 56 3 1970.38 2+M1+E2>1.5 B(M1)(W.u.) <0.0025; B(E2)(W.u.) >2.3
# Mult.,δ: from33S(α,nγ).
# 4439.8 100 3 0.0 0+E2 B(E2)(W.u.) =0.39 8
# Mult.: from33S(α,nγ).
# 4951.4 2+537.0<7 4414.40 4+
# 773.1<2.4 4178.32 3−
# 2980.9 18 5 1970.38 2+
# 4951.0 100 5 0.0 0+
# 4974.05 2−533.9<0.3 4440.11 2+
# 559.6<0.5 4414.40 4+
# 795.7 100 3 4178.32 3−M1+E2−0.21 7B(M1)(W.u.)=0.0033 10; B(E2)(W.u.)=0.86
# 3003.5 5.1 13 1970.38 2+
# 4973.7 23 3 0.0 0+
# 5171.13 5−197.1<5 4974.05 2−
# 219.7<4 4951.4 2+
# 731.0<0.4 4440.11 2+
# 756.7 14.6 24 4414.40 4+
# ...
# Mult.,δ: D+Q fromγγ(θ) in88Rbβ−decay.
# ∆π=yes from level scheme.
# 4845.19 18 0.60 5 0 0+[E3] 1.18 ×10−3α(K)=3.93×10−56;α(L)=4.17×10−66;
# α(M)=6.99×10−710;α(N)=8.81×10−813;
# α(O)=5.85×10−99
# B(E3)(W.u.)=8.724
# 4853.026 1−338.95 7 12.8 6 4514.028 2−M1 0.00666 α(K)=0.00588 9;α(L)=0.000649 9;α(M)=0.0001092
# 16;α(N)=1.371×10−520
# α(O)=8.90×10−713
# B(M1)(W.u.)=0.26 4
# Mult.: D from comparison to RUL, ∆π=no from
# level scheme.
# Eγ,Iγ: from88Rbβ−decay.
# Iγ: Other: 85.9 9in (n,n′γ).
# 439.2 3 3.29 4413.96 (2)+
# 1217.97 18 11.1 9 3635.09 (3)+
# 1366.26 12 345 3486.56 1+E1+M2−0.05 2 2.94×10−4α(K)=0.0001266 21;α(L)=1.347×10−522;
# α(M)=2.26×10−64;α(N)=2.84×10−75;
# α(O)=1.87×10−83
# B(E1)(W.u.)=0.00016 4; B(M2)(W.u.)=1.09
# Mult.,δ: D+Q fromγγ(θ) in88Rbβ−decay.
# ∆π=yes from level scheme.
# 2118.867 20 100.0 13 2734.137 3−(E2) 4.91 ×10−4α(K)=0.0001114 16;α(L)=1.187×10−517;
# α(M)=1.99×10−63;α(N)=2.51×10−74
# 18
# 88Sr38.pdf
# ================================================================================
# ================================================================================
# 88
# 38Sr50-24 From ENSDF88
# 38Sr50-24Adopted Levels ,Gammas (continued)
# γ(88Sr) (continued)
# Ei(level) JπiEγ†Iγ†Ef Jπ
# fMult.‡α Comments
# α(N)=5.07×10−88;α(O)=3.37×10−95
# B(E2)(W.u.)=0.011 4
# Mult.: Q fromγ(θ) in (n,n′γ),∆π=no from level scheme.
# 5710.78 3874.6 1 100 1836.090 2+
# 5730.18 4+3894.0 2 100 1836.090 2+[E2] 1.17×10−3α(K)=4.02×10−56;α(L)=4.25×10−66;α(M)=7.13×10−710;
# α(N)=8.99×10−813;α(O)=5.96×10−99
# B(E2)(W.u.)<0.14
# 5772.23 0+1736.7 1 10014 4035.52 2+[E2] 3.66×10−4α(K)=0.0001610 23;α(L)=1.724×10−525;α(M)=2.89×10−64;
# α(N)=3.64×10−75;α(O)=2.39×10−84
# B(E2)(W.u.)=3618
# 3935.8 6 6914 1836.090 2+[E2] 1.19×10−3α(K)=3.96×10−56;α(L)=4.18×10−66;α(M)=7.01×10−710;
# α(N)=8.84×10−813;α(O)=5.86×10−99
# B(E2)(W.u.)=0.42 21
# 5800.71 (1−,2,3+) 2314.2 1 3486.56 1+
# 3066.2 2 2734.137 3−
# 5812.08 3−1513.5 6 2613 4299.52 4+[E1] 3.75×10−4α(K)=0.0001057 15;α(L)=1.123×10−516;α(M)=1.88×10−63;
# α(N)=2.37×10−74
# α(O)=1.559×10−822
# B(E1)(W.u.)=0.0012 11
# Eγ: observed only in (n, γ), E=thermal.
# 1643.1 7 2010 4170.41 (3−) E γ: observed only in (n, γ), E=thermal.
# 2177.22 21 396 3635.09 (3)+[E1] 8.14×10−4α(K)=5.99×10−59;α(L)=6.34×10−69;α(M)=1.062×10−615;
# α(N)=1.337×10−719;α(O)=8.84×10−913
# B(E1)(W.u.)=0.0006 5
# Eγ: observed only in (n, γ), E=thermal.
# 3077.94 9 885 2734.137 3−
# 3975.66 14 10010 1836.090 2+[E1] 1.69×10−3α(K)=2.62×10−54;α(L)=2.76×10−64;α(M)=4.62×10−77;
# α(N)=5.83×10−89;α(O)=3.87×10−96
# B(E1)(W.u.)=0.00026 19
# 5811.79 15 23.5 14 0 0+[E3] 1.43×10−3α(K)=2.91×10−54;α(L)=3.08×10−65;α(M)=5.17×10−78;
# α(N)=6.52×10−810;α(O)=4.33×10−96
# B(E3)(W.u.)=1.3×10210
# Eγ: observed only in (n, γ), E=thermal.
# 5831.5 (1,2+) 5831.3 5 100 0 0+
# 5835.58 (3−,4+) 1608.2b8<26b4227.20 (3−) E γ: observed only in (n, γ), E=thermal.
# 1665.31 13 10017 4170.41 (3−) E γ: observed only in (n, γ), E=thermal.
# 2250.72 11 364 3584.784 5−Eγ: observed only in (n, γ), E=thermal.
# 2349.21d20 13.7 21 3486.56 1+Eγ: placement is questionable, if Jπ=(4+) assignment to 5835.58 level is
# correct, as this transition would imply M3 multipolarity.
# Eγ: observed only in (n, γ), E=thermal.
# 24
# 90Zr40.pdf
# ================================================================================
# ================================================================================
# Continued on next page (footnotes at end of table)90
# 40Zr50-5 From ENSDF90
# 40Zr50-5
# Adopted Levels ,Gammas (continued)
# 90Zr Levels (continued)
# E(level)†JπT1/2‡XREF Comments
# 5307.75 15 (3−,4+) 0.07 ps+8−2G P X Jπ: 2988.9γto 5−, 3121.3γto 2+.
# 5312.77 20 1,2+59 fs 10 N V X XREF: Others:AB
# Jπ: 5312.6γto 0+.
# 5317.7 3 3−0.19 ps+11−6 O X XREF: Others:AB,AH
# Jπ: from L(p,t)=3.
# 5359.22 19 3,4 22.9 fs 28 X Jπ: shape of excitation function in (n,n′γ)
# consistent with J=3 or 4.
# 5379.8 3 (4+) 20 fs 4 H N V X Jπ: from L(p,p′)=L(α,α′)=4.
# 5426.01 13 3−52 fs+19−14C G I X XREF: Others:AH
# Jπ: E2 3106.8γto 5−, 2118.1γto 2+.
# 5432.790 22 7+,8+C Jπ: feeding from 8+parent in90Nbεdecay,
# M1,E2 1843.3γto 8+, 1984.5γto 6+.
# 5437.33 13 2+24.3 fs 35 V X XREF: Others:AG
# XREF: V(5433).
# Jπ: from L(p,p′)=2, E2 5436.9γto 0+.
# 5441#5 0+XREF: Others:AB
# Jπ: from L(p,t)=0.
# 5457.70 18 (4+) 115.9 fs 28 H N V X XREF: N(5464)V(5462).
# Jπ: from L(t,t′)=4.
# 5504.75 19 7.7 fs 7 I N VWX Z
# 5513.41 16 (3,4) 0.16 ps +8−6 X XREF: Others:AB
# XREF: AB(5507).
# Jπ: from L(p,t)=3,4.
# 5564.2 4 7.6 fs 28 I X XREF: Others:AH
# 5582@6 (3−) N V Jπ: from L(α,α′)=(3).
# 5590.58 14 2+15.9 fs 21 X XREF: Others:AB
# Jπ: from L(p,t)=2.
# 5601.8 4 24 fs 4 X
# 5607.6 4 14 fs+9−7G MN X XREF: Others:AA
# 5631@7 3−I K V B(E3)↑=0.0068 10(1975Si21 )
# Jπ: from (e,e′).
# 5644.02 4 10+<28gps E H XREF: Others:AH,AL
# Jπ: E2 2054.6γto 8+.
# 5651.1 3 45 fs 5 G X
# 5666@7 3−NO V Jπ: from L(α,α′)=3.
# 5703@7 V
# 5724.3 4 22 fs 4 X
# 5753@7 G K V XREF: Others:AA
# 5775.1 5 24 fs+21−6H N X
# 5781@7 3−V XREF: Others:AA
# B(E3)↑=0.00145 22(1975Si21 )
# Jπ: from (e,e′), L(p,p′)=3.
# 5785.0 4 Z
# 5792.05 3 (9+) E Jπ: (M1+E2) 2202.6γto 8+.
# 5808 4 O Z
# 5821.8 6 X
# 5829@7 V
# 5846.4 5 14 fs+44−13G K X
# 5884.4 4 N VW Z
# 5938#5 HI N V XREF: Others:AB,AH
# Jπ: L(p,p′)=3 and L(p,t)=(1) are in conﬂict.
# 5977@7 V
# 6006@7 V
# 5
# 90Zr40.pdf
# ================================================================================
# ================================================================================
# 90
# 40Zr50-14 From ENSDF90
# 40Zr50-14Adopted Levels ,Gammas (continued)
# γ(90Zr)
# Ei(level) JπiEγ†@Iγ†Ef Jπ
# fMult.‡δ‡α Comments
# 1760.74 0+1760.70#20#0 0+E0#Eγ: from90Nbεdecay. Probability of two-photon decay
# is 0.040% 5, see90Yβ−decay. Other: 0.018% 2with a
# ratio<2E1>/<2M1>of 1.9 7(1984Sc37 ). Probability of
# one-photon E0 transition for 1760.7 relative to internalconversion is 5×10−72(
# 1990Zh20 ), see90Yβ−decay.
# 2186.273 2+425.5 2 0.027 5 1760.74 0+[E2]#0.00688α(K)=0.00602 9;α(L)=0.000713 10;α(M)=0.0001239 18;
# α(N)=1.732×10−525
# α(O)=1.117×10−616
# B(E2)(W.u.)=5.210
# 2186.242#25 100.0#9 0 0+E2#5.36×10−4α(K)=0.0001223 18;α(L)=1.325×10−519;
# α(M)=2.29×10−64;α(N)=3.27×10−75;
# α(O)=2.34×10−84
# B(E2)(W.u.)=5.38 13
# 2319.000 5−132.716#18 5.04#52186.273 2+E3(+M4)#<0.07 3.0 9α(K)=2.27;α(L)=0.65 19;α(M)=0.12 4;α(N)=0.015 5;
# α(O)=0.00037 21
# B(E3)(W.u.)=0.180 10
# δ: from90Nbεdecay.
# 2318.959#25 100.0#2 0 0+E5#4.64×10−4α(K)=0.000408 6;α(L)=4.63×10−57;α(M)=8.04×10−6
# 12;α(N)=1.141×10−616;α(O)=7.97×10−812
# B(E5)(W.u.)=8.74 33
# 2739.29 (4)−420.28#5 100#2319.000 5− #
# 2747.875 3−429.0e3 0.53 11 2319.000 5−[E2] B(E2)(W.u.) =0.53+18−13
# 561.604 11 100.0 3 2186.273 2+E1 B(E1)(W.u.) =1.17×10−4+27−18
# Eγ: from90Nbεdecay.
# Mult.: D fromγ(θ) in (n,n′γ); E1 from∆π=yes.
# 2747.47 5 6.13 0 0+E3 B(E3)(W.u.) =8.0+18−13
# Mult.: O fromγ(θ) in (n,n′γ); M3 excluded by
# comparison to RUL.
# 3076.925 4+329.09 3 6.74 18 2747.875 3−E1 E γ: weighted average of 329.058 16(90Nbεdecay) and
# 329.125 15(90Zr(n,n′γ)).
# Iγ: weighted average of 6.82 23(90Nbεdecay) and 6.6 3
# (90Zr(n,n′γ)).
# Mult.: D fromγ(θ) in (n,n′γ);∆π=yes from level
# scheme.
# 337.61 14 0.90 11 2739.29 (4)−Eγ: weighted average of 337.50 15(90Nbεdecay) and
# 337.8 2(90Zr(n,n′γ)).
# Iγ: weighted average of 1.4 5(90Nbεdecay) and 0.88 11
# (90Zr(n,n′γ)).
# 14
# 90Zr40.pdf
# ================================================================================
# ================================================================================
# 90
# 40Zr50-15 From ENSDF90
# 40Zr50-15Adopted Levels ,Gammas (continued)
# γ(90Zr) (continued)
# Ei(level) JπiEγ†@Iγ†Ef Jπ
# fMult.‡δ‡α Comments
# 3076.925 4+757.86 7 2.66 21 2319.000 5−Eγ: weighted average of 757.95 5(90Nbεdecay) and
# 757.80 4(90Zr(n,n′γ)).
# Iγ: weighted average of 2.23 23(90Nbεdecay) and 2.76 11
# (90Zr(n,n′γ)).
# 890.629 14 100.0 3 2186.273 2+E2b8.82×10−4α(K)=0.000777 11;α(L)=8.69×10−513;α(M)=1.507×10−5
# 22;α(N)=2.13×10−63
# α(O)=1.479×10−721
# 3308.10 2+1121.990 22 454 2186.273 2+M1+E2+0.25 B(E2)(W.u.) =3.5+15−13; B(M1)(W.u.)=0.065 6
# Mult.: D+Q fromγ(θ) in (n,n′γ);∆π=no from level
# scheme.
# 1547.5 3.9 10 1760.74 0+[E2] B(E2)(W.u.) =1.03 26
# 3308.1 2 1004 0 0+E2 B(E2)(W.u.) =0.589 38
# Mult.: Q fromγ(θ) in (n,n′γ); M2 excluded by comparison
# to RUL.
# 3448.230 6+371.307#8 1.95#73076.925 4+E2#0.01064α(K)=0.00929 13;α(L)=0.001119 16;α(M)=0.000194 3;
# α(N)=2.71×10−54;α(O)=1.712×10−624
# B(E2)(W.u.)<46
# 1129.224#15 100.0#4 2319.000 5−E1#2.42×10−48α(K)=0.000203 7;α(L)=2.20×10−58;α(M)=3.82×10−614;
# α(N)=5.42×10−720;α(O)=3.86×10−814
# B(E1)(W.u.)<1.6×10−4
# 3589.418 8+141.178#15 100.0#10 3448.230 6+E2#α(K)=0.27 3;α(L)=0.040 5;α(M)=0.0071 9;α(N)=0.00095
# 13;α(O)=4.6×10−57
# B(E2)(W.u.)=2.41 7
# 1270.396#18 1.94#42319.000 5−(E3)#7.63×10−4α(K)=0.000667 10;α(L)=7.56×10−511;α(M)=1.313×10−5
# 19;α(N)=1.86×10−63
# α(O)=1.285×10−718
# B(E3)(W.u.)=0.0523 20
# 3842.34 2+1656.05 11 17.0 15 2186.273 2+M1+E2+1.1 3.72×10−410α(K)=0.000208 5;α(L)=2.27×10−55;α(M)=3.93×10−68;
# α(N)=5.59×10−712;α(O)=4.00×10−810
# B(E2)(W.u.)=10.0+20−23; B(M1)(W.u.)=0.022 5
# Mult.: D+Q fromγ(θ) in (n,n′γ);∆π=no from level
# scheme.
# 3842.2 10 100.0 15 0 0+E2 B(E2)(W.u.) =1.60+14−12
# Mult.: Q fromγ(θ) in (n,n′γ); M2 excluded by comparison
# to RUL.
# 3932.4 3932.3a6 100a0 0+ a
# 3958.59 5−1219.33 3 53.8 12 2739.29 (4)−(M1+E2)+0.08 B(E2)(W.u.) =0.59+32−22; B(M1)(W.u.)=0.128+29−20
# Mult.: D+Q fromγ(θ) in (n,n′γ);∆π=no from level
# scheme.
# 15
# 92Zr40.pdf
# ================================================================================
# ================================================================================
# Continued on next page (footnotes at end of table)92
# 40Zr52-2 From ENSDF92
# 40Zr52-2
# Adopted Levels ,Gammas (continued)
# 92Zr Levels (continued)
# E(level)‡JπT1/2#XREF Comments
# µ=−0.360 20(1999Ja13 )
# Jπ: L=2 in (t,p), (p,t) and p,d,t,3He,αscattering.µ
# implies dominant role of d 5/2neutrons in
# wavefunction of this state ( 1999Ja13 ).
# T1/2: from B(E2)=0.080 6(Coulomb excitation).
# µ: from measured g-factor =−0.180 10fromγ(θ,H,t) in
# Coulomb excitation. Other µ:−0.06 10from transient
# ﬁeld integral PAC ( 1989Ra17 , from 1980Ha31 ),
# assuming T 1/2=4.85 ps;−0.36 4(2008We07 ; transient
# ﬁeld).
# 1382.77 7 0+88 ps 3A EFG IJ L NO QRS WX XREF: Others:AA,AC,AD,AH
# Jπ: 448γ-934γ(θ) in92Yβ−decay indicates a 0-2-0
# cascade; L=0 in (t,p) and (p,t).
# T1/2: from92Yβ−decay. Other: 85 ps 15from
# (p,p′γ).
# 1495.46b54+102 ps 3A CDEFGHIJKLMN PQ STUVWX XREF: Others:AA,AC,AD,AF,AG,AH,AI,AJ,
# AK,AL
# µ=−2.04(1999Ja13 )
# µ: from measured g-factor =−0.50 11fromγ(θ,H,t) in
# Coulomb excitation.
# Jπ: L=4 in (t,p), (p,t), (p,p′), (t,t′), (α,α′).µimplies
# dominant role of d 5/2neutrons in wavefunction of
# this state ( 1999Ja13 ).
# T1/2: fromγγ(t),92Yβ−decay.
# 1847.27 4 2+96&fs10AB EFGHIJKLMN P R T WX Z XREF: Others:AA,AC,AD,AF,AH
# µ=+1.510(2008We07 )
# Jπ: L=2 in (p,t), (p,p′), (t,t′), (α,α′), (3He,3He′), (t,p).
# µ: From measured g-factor in Coulomb excitation
# (transient ﬁeld).
# Level exhibits structure expected for a mixed symmetry
# one-phonon Q excitation ( 2002We15 ).
# 2066.65 5 2+>0.76&psAB EFGHIJKLM WX XREF: Others:AC,AD,AF,AL
# Jπ: L=2 in (t,p), (p,p′), (α,α′).
# 2182 10 (2+) K Jπ: L(α,α′)=(2).
# Probably same level as in (p,p′) at E=2180? 22.
# 2339.66 4 3−0.28&ps3A EFGHIJKLMN P R T VWX XREF: Others:AD,AL
# Jπ: L=3 in (t,p), (p,t), (p,p′), (d,d′), (t,t′), (3He,3He′),
# (α,α′).
# For summary of B(E3) ↑data, see 1989Sp01 ;
# recommended value is 0.067 22based on b 3from
# angular distribution in (p,p′). This corresponds to
# 4.4% 15of energy-weighted E3 sum rule.
# 2398.36 6 4+149&fs16EFGHI K N WX XREF: Others:AB,AD,AF,AG
# XREF: X(2360).
# Jπ: L=4 in (t,p) and (α,α′). Note: evaluator assumes
# J=1,3 from (n,n′) for 2360 20level to be in error;
# alternatively, an additional level may exist at that
# energy.
# 2473.4? 5 (≤2) A Jπ:γray to 0+state.
# 2486.01 9 5−≤3.5 ns DEF IJKL N R WX XREF: Others:AB,AC,AD,AE,AG
# XREF: R(2450).
# Jπ: L=5 in (t,p), (p,p′), (α,α′) and analyzing power in
# (pol p,p′) (1979De11 ). See comment on J(2486 level)
# in (n,γ).
# 2
# 92Zr40.pdf
# ================================================================================
# ================================================================================
# 92
# 40Zr52-11 From ENSDF92
# 40Zr52-11Adopted Levels ,Gammas (continued)
# γ(92Zr) (continued)
# Ei(level) JπiEγ†Iγ†Ef Jπ
# fMult.‡δ‡αaComments
# fromεdecay, (n,γ) E=thermal and (n,n′γ), respectively. Other E γ:
# 1132.4 1fromβ−decay.
# Mult.: D+Q fromγγ(θ) in (n,γ) and (n,n′γ); adopted∆π=no.
# δ: fromδ=−3.2+5−4or+0.85 7from 2005Fr17 in (n,n′γ) and−2.7
# +8−15from (n,γ) E=thermal. Otherδ:−2.4+3−4or−1.04 11
# (1978Gl04 ) in (n,n′γ).
# 2066.65 2+2066.7@4 0.53@7 0.0 0+E2 B(E2)(W.u.) <0.0042
# Mult.,δ: Q (δ=0) fromγ(θ) in (n,n′γ); not M2 from RUL.
# 2339.66 3−272.85b24 2066.65 2+Eγ,Iγ: Eγfrom (n,γ) E=thermal. Branch absent in β−decay and
# (n,n′γ) and one (n,γ) E=thermal study, and I γdata from the two
# (n,γ) E=thermal studies that report it are discrepant.
# 492.37 10 10.8 5 1847.27 2+(E1(+M2))≤0.009 B(E1)(W.u.) =0.00067; B(M2)(W.u.) ≤1.3
# Iγ: unweighted average of 11.7 7from (n,n′γ), 10.6 9from (n,γ)
# E=thermal and 10.1 6fromβ−decay. Weighted average is 10.7 5.
# Mult.: D(+Q) fromγ(θ) in (n,n′γ),∆π=yes from level scheme.
# δ:+0.01 3from (n,n′γ); however, B(M2)(W.u.) exceeds RUL, unless
# δ<0.009.
# 844.12 6 29.9 19 1495.46 4+(E1+M2)≤0.02 B(E1)(W.u.) ≥0.00036; B(M2)(W.u.) ≤1.2
# Mult.: D+Q fromγ(θ) in (n,n′γ),∆π=yes from level scheme.
# δ:+0.13 4(1978Gl04 ) from (n,n′γ); however, B(M2)(W.u.) exceeds
# RUL, unlessδ<0.02.
# Iγ: unweighted average of 32.3 18from (n,n′γ), 31.1 22from (n,γ)
# E=thermal and 26.2 17fromβ−decay. Weighted average is 29.6
# 20.
# 1405.06 5 1004 934.51 2+(E1) B(E1)(W.u.) =0.00030 4
# Iγ: weighted average from (n,n′γ), (n,γ) E=thermal andβ−decay.
# Mult.: mult=D(+Q) fromγγ(θ) in (n,γ),92Yβ−decay, and from
# γ(θ) in (n,n′γ); adopted∆π=yes.
# δ:−0.019+21−20fromγγ(θ) in92Yβ−decay. Others:+0.03 2
# fromγ(θ) in (n,n′γ); evaluator rejects value of +0.18+20−15from
# γγ(θ) in (n,γ). B(M2)(W.u.) exceeds RUL, unless δ<0.04.
# 2339.9 1≈0.11 0.0 0+E3 0.00049 B(E3)(W.u.) =18.3 11
# Eγ,Iγ: fromβ−decay. Other Eγ(Iγ): 2339.4 22(0.4 7) in (n,γ)
# E=thermal.
# Mult.: from form factor in (e,e′).
# B(E3)(W.u.): from (e,e′). However, B(E3)(W.u.) =4813from adopted
# T1/2and branching=0.30 7fromβ−decay; a branch of 0.11 would
# Be required to reduce this B(E3)(W.u.) to the value obtained in
# (e,e′), suggesting branching may be overestimated in β−decay.
# 11
# 96Zr40.pdf
# ================================================================================
# ================================================================================
# 96
# 40Zr56-6 From ENSDF96
# 40Zr56-6Adopted Levels ,Gammas (continued)
# γ(96Zr)
# Ei(level) JπiEγ†Iγ Ef Jπ
# fMult.δ α Comments
# 1581.64 0+1581.6 4 0.0 0+E0#Eγ: from96Yβ−decay (5.34 s).
# ρ2=7.53×10−314=0.32 1(SPU); from t, K,L I,LIIshell
# conversion factors from 1970Be87 , and the K-shell
# conversion/pair production ratio from 1986PaZM .
# 1750.497 2+1750.42 2 100 0.0 0+E2 0.000398 6α(K)=0.000184 3;α(L)=2.01×10−53;α(M)=3.48×10−65;
# α(N)=4.94×10−77
# α(O)=3.52×10−85;α(N+..)=0.000190 3
# B(E2)(W.u.)=2.33
# Mult.: stretched Q from γγ(θ) inβ-decay; E2 from RUL.
# 1897.158 3−146.653f10 100f4 1750.497 2+(E1) 0.0371 α(K)=0.0327 5;α(L)=0.00366 6;α(M)=0.000632 9;
# α(N)=8.84×10−513;α(O)=5.80×10−69
# α(N+..)=9.42×10−514
# B(E1)(W.u.)=0.00123 10
# Mult.: stretched D from γγ(θ) inβ−decay and∆Jπ.
# 1897.21g3 19.0g4 0.0 0+[E3] 0.000440 7α(K)=0.000268 4;α(L)=2.97×10−55;α(M)=5.14×10−68;
# α(N)=7.31×10−711
# α(O)=5.17×10−88;α(N+..)=0.0001367 20
# B(E3)(W.u.)=574
# Iγ(147) and Iγ(1897): weighted average of (p,p′γ),
# (n,n′γ) andβ-decay(5.34 s) data sets.
# 2225.846 2+328.75 3 14b1 1897.158 3−(E1(+M2))−0.02@5 0.00380 16α(K)=0.00336 14;α(L)=0.000371 17;α(M)=6.4×10−53;
# α(N)=9.1×10−65;α(O)=6.2×10−73
# α(N+..)=9.7×10−65
# B(E1)(W.u.)>6.4×10−5
# Mult.: fromγ(θ) in (n,n′γ) and∆Jπ.
# 475.33 1 57b1 1750.497 2+M1+E2−0.09@+1−2 0.00361 5α(K)=0.00318 5;α(L)=0.000355 5;α(M)=6.16×10−59;
# α(N)=8.76×10−613;α(O)=6.19×10−79
# α(N+..)=9.38×10−614
# B(E2)(W.u.)>0.16; B(M1)(W.u.) >0.0058
# Mult.: fromγ(θ) in (n,n′γ) and ce data in (t,p γ).
# 644.18 6 28b2 1581.64 0+E2 0.00203 3α(K)=0.001783 25;α(L)=0.000204 3;α(M)=3.53×10−55;
# α(N)=4.98×10−67;α(O)=3.37×10−75
# α(N+..)=5.31×10−68
# B(E2)(W.u.)>2.7
# Mult.: Q fromγ(θ) in (n,n′γ); E2 from RUL.
# 2225.93 4 100b5 0.0 0+E2 0.000550 8α(K)=0.0001185 17;α(L)=1.283×10−518;
# α(M)=2.22×10−64
# α(O)=2.26×10−84;α(N+..)=0.000417 6
# 6

# %%
for i in range(61):
    page = reader.pages[i] 
    text = page.extract_text() 
    if "B(E3)" in text:
        print("================================================================================")
        print("================================================================================")
        print(text)

# %% [markdown]
# # Values of  $E_{3_1^-}$

# %%
first3 = pd.read_csv("First_3_minus_EvenEven.csv")
first3["a"] = first3["n"] + first3["z"]

# %%
first3.sort_values(by=["firstThreeMinusEnergy(keV)"]).head(12)
# Lowest values: 224Ra, 224Th (Quartet), 226Th, 222Ra, 226Ra, 228Th, 230U, 22Th, 220Ra (Quartet), 228Ra, 230Th, 232Th
# Out:
#       z    n  firstThreeMinusEnergy(keV)    a
# 298  88  136                     290.352  224
# 296  90  134                     305.300  224
# 299  90  136                     307.500  226
# 295  88  134                     317.290  222
# 301  88  138                     321.540  226
# 302  90  138                     396.094  228
# 303  92  138                     435.190  230
# 293  90  132                     467.000  222
# 292  88  132                     474.170  220
# 304  88  140                     537.500  228
# 305  90  140                     571.756  230
# 306  92  140                     628.965  232

# %%
#%matplotlib notebook

# Data
N = first3["n"].to_numpy()
Z = first3["z"].to_numpy()
E = first3["firstThreeMinusEnergy(keV)"].to_numpy()
magic = [2, 8, 20, 28, 50, 82, 126]

# Canvas
fig = plt.figure(figsize = (15,15))
ax = plt.axes(projection ="3d")
 
#Plots
ax.scatter(N, Z, E, "o", s= 10, c = "C0", alpha=1)
ax.scatter(N, Z, 0, "o", s= 10, c = "C0", alpha=0.5)
ax.scatter(N, max(Z), E, "o", s= 10, c = "C1", alpha=1)
ax.scatter(min(N), Z, E, "o", s= 10, c = "C2", alpha=1)
for i in range(len(N)):
    ax.plot([N[i], N[i]], [Z[i], Z[i]], [E[i], 0], color='C0', alpha=0.1)  
#for i in range(len(magic)):
    #ax.plot([magic[i], magic[i]], [105, 105], [0, max(E)], color='C1', alpha=0.4)  
    #if i < len(magic)-1:
    #    ax.plot([0,0], [magic[i], magic[i]], [0, max(E)], color='C2', alpha=0.4)  

    
# Format the axis
ax.invert_xaxis()
ax.set_xlabel('N', fontsize=14, labelpad=10)
ax.set_ylabel('Z', fontsize=14, labelpad=10)
ax.set_zlabel(r'$E(3^{-}_1)$ [keV]', fontsize=14, labelpad=10, rotation=-180)
ax.view_init(35, -135) 
ax.set_xticks(np.arange(min(N), max(N)+10, 10))
ax.set_yticks(np.arange(min(Z), max(Z)+10, 10))
ax.set_zticks(np.arange(300, 9600, 1000))

# Plot the planes
X, Y = np.meshgrid(np.linspace(min(N), max(N), 10), np.linspace(min(Z), max(Z), 10))
Z_xy = np.zeros_like(X)
X_xz, Z_xz = np.meshgrid(np.linspace(min(N), max(N), 10), np.linspace(0, max(E), 10))
Y_xz = np.full((len(X_xz[0]), len(X_xz[0])), max(Z))
Y_yz, Z_yz = np.meshgrid(np.linspace(min(Z), max(Z), 10), np.linspace(0, max(E), 10))
X_yz = np.full((len(X_xz[0]), len(X_xz[0])), min(N))
ax.plot_surface(X, Y, Z_xy, color='blue', alpha=0.05, rstride=100, cstride=100)
ax.plot_surface(X_xz, Y_xz, Z_xz, color='red', alpha=0.05, rstride=100, cstride=100)
ax.plot_surface(X_yz, Y_yz, Z_yz, color='green', alpha=0.05, rstride=100, cstride=100)
ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))

# Maximum values
ax.set_xlim(max(N), min(N))
ax.set_ylim(min(Z), max(Z))
ax.set_zlim(min(E), max(E))

plt.show()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(first3["a"], first3["firstThreeMinusEnergy(keV)"], ".")
plt.show()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(first3["n"], first3["firstThreeMinusEnergy(keV)"], ".")
plt.show()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(first3["z"], first3["firstThreeMinusEnergy(keV)"], ".")
plt.show()
