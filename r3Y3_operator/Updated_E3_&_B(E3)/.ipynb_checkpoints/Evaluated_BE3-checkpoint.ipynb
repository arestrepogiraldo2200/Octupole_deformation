# 23    Reported value of upwards transition as 0.020(3)
# 24    Reported value of upwards transition as 0.026(5)
# 25    Reported value of upwards transition as 0.040(7)
# 26    Reported value of upwards transition as 0.038(8)
# 27   Reported value of upwards transition as 0.073(10)
# 28   Reported value of upwards transition as 0.061(15)
# 29    Reported value of upwards transition as 0.020(7)
# 30                                                 NaN
# 31    Reported value of upwards transition as 0.021(5)
# 32    Reported value of upwards transition as 0.032(7)
# 33    Reported value of upwards transition as 0.027(3)
# 34   Reported value of upwards transition as 0.030(10)
# 35   Reported value of upwards transition as 0.042(14)
# 36   Reported value of upwards transition as 0.043(15)
# 37   Reported value of upwards transition as 0.042(15)
# 38   Reported value of upwards transition as 0.036(12)
# 39   Reported value of upwards transition as 0.043(18)
# 40   Reported value of upwards transition as 0.0497...
# 41                                                 NaN
# 42                                                 NaN
# 43                                                 NaN
# 44                                                 NaN
# 45   Reported value of upwards transition as 0.0760...
# 46                                                 NaN
# 47   Reported value of upwards transition as 0.143(12)
# 48    Reported value of upwards transition as 0.053(9)
# 49   Reported value of upwards transition as 0.065(10)
# 50    Reported value of upwards transition as 0.060(6)
# 51   Reported value of upwards transition as 0.128(19)
# 52   Reported value of upwards transition as 0.093(26)
# 53   Reported value of upwards transition as 0.086(12)
# 54     Reported value of upwards transition as 0.11(1)
# 55      Reported value of upwards transition as 0.0207
# 56   Reported value of upwards transition as 0.087(12)
# 57                                                 NaN
# 58   Reported value of upwards transition as 0.118(10)
# 59   Reported value of upwards transition as 0.092(10)
# 60   Reported value of upwards transition as 0.076(11)
# 61                                                 NaN
# 62     Reported value of upwards transition as 0.12(4)
# 63     Reported value of upwards transition as 0.09(3)
# 64   Reported value of upwards transition as 0.117(20)
# 65   For some Telurium isotopes, the reported 3- in...
# 66   Reported value of upwards transition as 0.176(22)
# 67   Reported value of upwards transition as 0.133(13)
# 68     Reported value of upwards transition as 0.19(3)
# 69    Reported value of upwards transition as 0.163(9)
# 70                                                 NaN
# 71                                                 NaN
# 72   Unclear value of in 3- level 0.352(21). The re...
# 73     Reported value of upwards transition as 0.32(2)
# 74     Reported value of upwards transition as 0.37(3)
# 75     Reported value of upwards transition as 0.31(3)
# 76     Reported value of upwards transition as 0.10(2)
# 77                                                 NaN
# 78                                                 NaN
# 79     Reported value of upwards transition as 0.21(5)
# 80    Reported value of upwards transition as 0.171(7)
# 81    Reported value of upwards transition as 0.118(7)
# 82     Reported value of upwards transition as 0.22(7)
# 83     Reported value of upwards transition as 0.23(5)
# 84   Reported value of upwards transition as 0.171(10)
# 85    Reported value of upwards transition as 0.104(7)
# 86    Reported value of upwards transition as 0.088(6)
# 87     Reported value of upwards transition as 0.19(4)
# 88     Reported value of upwards transition as 0.15(3)
# 89   Reported value of upwards transition as 0.061(10)
# 90                                                 NaN
# 91                                                 NaN
# 92       Reported value of upwards transition as 0.016
# 93                                                 NaN
# 94                                                 NaN
# 95    Reported value of upwards transition as 0.101(8)
# 96    Reported value of upwards transition as 0.147(8)
# 97   Reported value of upwards transition as 0.154(13)
# 98    Reported value of upwards transition as 0.131(9)
# 99                                                 NaN
# 100  Reported value of upwards transition as 0.157(13)
# 101   Reported value of upwards transition as 0.103(4)
# 102                                                NaN
# 103    Reported value of upwards transition as 0.40(3)
# 104                                                NaN
# 105    Reported value of upwards transition as 0.63(7)
# 106    Reported value of upwards transition as 0.66(4)
# 107    Reported value of upwards transition as 0.64(4)
# 108   Reported value of upwards transition as 0.611(9)
# 109   Reported value of upwards transition as 0.47(11)
# 110   Reported value of upwards transition as 1.10(11)
# 111    Reported value of upwards transition as 0.64(6)
# 112    Reported value of upwards transition as 0.59(7)
# 113    Reported value of upwards transition as 0.70(5)
# 114  Reported value of upwards transition as 0.570(36)
# 115   Reported value of upwards transition as 0.71(12)
# 116    Reported value of upwards transition as 0.41(6)
# 117    Reported value of upwards transition as 0.42(7)
# 118   Reported value of upwards transition as 0.41(10)
# 119  Reported value of upwards transition as 0.202(20)

# %%
s = "Reported value of upwards transition as "

# Columns to store the computed values from inverse transition
BE3["Computed"] = np.nan
BE3["ComputedErr"] = np.nan

for i in range(len(BE3)):
    if s in str(BE3["Comments"].iloc[i]):
        
        value = str(BE3["Comments"].iloc[i]).split("as ")[1].split("(")
        
        # Extract measure of 0 -> 3
        measurestr = value[0]
        errorcorrec = len(measurestr.split(".")[1])
        
        # Convert to numbers
        measure = float(measurestr)
        error = float(value[1][:-1])*10**(-1*errorcorrec) if len(value)==2 else 0
        
        # Convert to 3->0 and convert to W.u.
        measureInWU = measure*10**6/BEWU(3, float(BE3["z"].iloc[i])+float(BE3["n"].iloc[i]))/7
        errorInWU = error*10**6/BEWU(3, float(BE3["z"].iloc[i])+float(BE3["n"].iloc[i]))/7
        
        #print(value, "---", measure, "---", error, "---", measureInWU, "---", errorInWU)
        
        # Append the values
        BE3["Computed"].iloc[i] = measureInWU
        BE3["ComputedErr"].iloc[i] = errorInWU

# Drop two rows
BE3 = BE3[(BE3["BE3"] != "<300") & (BE3["BE3"] != ">7.1")]
BE3 = BE3[(BE3["n"] != ".") & (BE3["z"] != ".")]
BE3
# Out:
# /tmp/ipykernel_13579/3424311851.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BE3["Computed"].iloc[i] = measureInWU
# /tmp/ipykernel_13579/3424311851.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BE3["ComputedErr"].iloc[i] = errorInWU
#       z    n   BE3   BE3unc        E_i E_f  \
# 0     6    6    12        2       9641   0
# 1     6    8   2.4      0.3     6728.2   0
# 2     8    8  13.5      0.7    6129.89   0
# 3    10   10    11        4     5621.4   0
# 4    12   12   5.6  1.1–0.8    7616.41   0
# 5    14   14  13.2      1.5    6878.79   0
# 6    16   16    16        3     5006.2   0
# 7    16   18    18        5   4624.404   0
# 8    16   20  15.4      1.5     4192.7   0
# 9    18   18  20.6        2    4178.32   0
# 10   18   20    17      8–5    3810.18   0
# 12   20   20    31      4–3    3736.69   0
# 13   20   22     .        .    3446.94   0
# 14   20   24     9      7–4   3307.872   0
# 15   20   28   8.4  4.5–3.5    4507.05   0
# 95   74  112     .        .     1045.4   0
# 96   76  112     .        .    1413.89   0
# 97   76  114   9.8  3.4–2.6   1386.992   0
# 98   76  116   8.6      0.6   1341.162   0
# 99   78  114  11.1        2   1378.046   0
# 100  78  116   7.7  1.1–0.9   1432.551   0
# 101  78  118   5.9      2.1   1447.043   0
# 102  80  122   2.5      0.1    2356.83   0
# 103  80  124     .        .    2675.25   0
# 104  80  130   2.2      0.9        663   0
# 105  84  126     .        .   2386.784   0
# 106  82  122     .        .     2620.6   0
# 107  82  124     .        .     2647.8   0
# 108  82  126  33.8      0.6   2614.522   0
# 109  82  126     .        .       1870   0
# 110  88  138     .        .     321.54   0
# 111  90  140     .        .    571.756   0
# 112  92  142     .        .    849.266   0
# 113  92  144     .        .     744.18   0
# 114  92  146     .        .     731.93   0
# 115  94  144     .        .     661.44   0
# 116  94  146     .        .     648.86   0
# 117  94  148     .        .      832.3   0
# 118  96  152     .        .       1095   0
# 119  98  152     .        .     905.89   0
#
#                                               Comments   Computed  ComputedErr
# 0    There is another 3 to 0 decay but from a higher 3        NaN          NaN
# 1                                                  NaN        NaN          NaN
# 2                                                  NaN        NaN          NaN
# 3                                                  NaN        NaN          NaN
# 4    There is another 3 to 0 decay but from a higher 3        NaN          NaN
# 5                                                  NaN        NaN          NaN
# 6    Reported value of upwards transition as 0.0127...  29.825525     4.696933
# 7     Reported value of upwards transition as 0.008(2)  16.642421     4.160605
# 8    Unclear value of in 3- level 0.008(3). The ref...        NaN          NaN
# 9                                                  NaN        NaN          NaN
# 10                                                 NaN        NaN          NaN
# 12   There is another 3 to 0 decay but from a higher 3        NaN          NaN
# 13   Reported value of upwards transition as 0.0110...  14.996104     2.453908
# 14   Reported value of upwards transition as 0.0072...   8.943582     1.490597
# 15   Reported value of upwards transition as 0.0069...   7.201964     1.043763
# 16                                                 NaN        NaN          NaN
# 17   Reported value of upwards transition as 0.0080...   8.350103     1.670021
# 18                                                 NaN        NaN          NaN
# 19   Reported value of upwards transition as 0.0033...   3.174375     1.250511
# 21   Reported value of upwards transition as 0.0139...   9.936722     0.929334
# 22   Reported value of upwards transition as 0.0176...  12.581749     1.143795
# 23    Reported value of upwards transition as 0.020(3)  12.512122     1.876818
# 24    Reported value of upwards transition as 0.026(5)  15.265033     2.935583
# 25    Reported value of upwards transition as 0.040(7)  23.484666     4.109816
# 26    Reported value of upwards transition as 0.038(8)  19.762874     4.160605
# 27   Reported value of upwards transition as 0.073(10)  35.827056     4.907816
# 28   Reported value of upwards transition as 0.061(15)  28.297572     6.958419
# 29    Reported value of upwards transition as 0.020(7)   8.783162     3.074107
# 30                                                 NaN        NaN          NaN
# 31    Reported value of upwards transition as 0.021(5)   9.222320     2.195791
# 32    Reported value of upwards transition as 0.032(7)  13.323157     2.914441
# 33    Reported value of upwards transition as 0.027(3)  10.672321     1.185813
# 34   Reported value of upwards transition as 0.030(10)  11.272640     3.757547
# 35   Reported value of upwards transition as 0.042(14)  16.601389     5.533796
# 36   Reported value of upwards transition as 0.043(15)  16.157450     5.636320
# 37   Reported value of upwards transition as 0.042(15)  14.314463     5.112308
# 38   Reported value of upwards transition as 0.036(12)  11.705499     3.901833
# 39   Reported value of upwards transition as 0.043(18)  14.655283     6.134770
# 40   Reported value of upwards transition as 0.0497...  16.160092     0.585275
# 41                                                 NaN        NaN          NaN
# 42                                                 NaN        NaN          NaN
# 43                                                 NaN        NaN          NaN
# 44                                                 NaN        NaN          NaN
# 45   Reported value of upwards transition as 0.0760...  21.593462     0.710311
# 46                                                 NaN        NaN          NaN
# 47   Reported value of upwards transition as 0.143(12)  34.389066     2.885796
# 48    Reported value of upwards transition as 0.053(9)  12.745598     2.164347
# 49   Reported value of upwards transition as 0.065(10)  15.024407     2.311447
# 50    Reported value of upwards transition as 0.060(6)  13.868684     1.386868
# 51   Reported value of upwards transition as 0.128(19)  27.395711     4.066551
# 52   Reported value of upwards transition as 0.093(26)  19.174311     5.360560
# 53   Reported value of upwards transition as 0.086(12)  17.092179     2.384955
# 54     Reported value of upwards transition as 0.11(1)  21.862089     1.987463
# 55      Reported value of upwards transition as 0.0207   3.968429     0.000000
# 56   Reported value of upwards transition as 0.087(12)  16.678905     2.300539
# 57                                                 NaN        NaN          NaN
# 58   Reported value of upwards transition as 0.118(10)  20.379913     1.727111
# 59   Reported value of upwards transition as 0.092(10)  14.864575     1.615715
# 60   Reported value of upwards transition as 0.076(11)  11.886515     1.720417
# 62     Reported value of upwards transition as 0.12(4)  19.388576     6.462859
# 63     Reported value of upwards transition as 0.09(3)  14.076137     4.692046
# 64   Reported value of upwards transition as 0.117(20)  17.722668     3.029516
# 66   Reported value of upwards transition as 0.176(22)  24.291210     3.036401
# 67   Reported value of upwards transition as 0.133(13)  16.794915     1.641608
# 68     Reported value of upwards transition as 0.19(3)  24.703593     3.900567
# 69    Reported value of upwards transition as 0.163(9)  20.583242     1.136498
# 70                                                 NaN        NaN          NaN
# 71                                                 NaN        NaN          NaN
# 72   Unclear value of in 3- level 0.352(21). The re...        NaN          NaN
# 73     Reported value of upwards transition as 0.32(2)  35.132648     2.195791
# 74     Reported value of upwards transition as 0.37(3)  42.910253     3.479210
# 75     Reported value of upwards transition as 0.31(3)  33.133210     3.206440
# 76     Reported value of upwards transition as 0.10(2)  10.140115     2.028023
# 77                                                 NaN        NaN          NaN
# 78                                                 NaN        NaN          NaN
# 79     Reported value of upwards transition as 0.21(5)  21.294242     5.070058
# 80    Reported value of upwards transition as 0.171(7)  16.897842     0.691725
# 81    Reported value of upwards transition as 0.118(7)  11.084762     0.657571
# 82     Reported value of upwards transition as 0.22(7)  21.739914     6.917245
# 83     Reported value of upwards transition as 0.23(5)  22.156339     4.816595
# 84   Reported value of upwards transition as 0.171(10)  16.063511     0.939387
# 85    Reported value of upwards transition as 0.104(7)   9.529885     0.641435
# 86    Reported value of upwards transition as 0.088(6)   7.868271     0.536473
# 87     Reported value of upwards transition as 0.19(4)  17.410366     3.665340
# 88     Reported value of upwards transition as 0.15(3)  13.411826     2.682365
# 89   Reported value of upwards transition as 0.061(10)   5.323509     0.872706
# 90                                                 NaN        NaN          NaN
# 91                                                 NaN        NaN          NaN
# 92       Reported value of upwards transition as 0.016   1.300611     0.000000
# 93                                                 NaN        NaN          NaN
# 94                                                 NaN        NaN          NaN
# 95    Reported value of upwards transition as 0.101(8)   7.020690     0.556094
# 96    Reported value of upwards transition as 0.147(8)  10.001980     0.544325
# 97   Reported value of upwards transition as 0.154(13)  10.258831     0.866005
# 98    Reported value of upwards transition as 0.131(9)   8.545809     0.587117
# 99                                                 NaN        NaN          NaN
# 100  Reported value of upwards transition as 0.157(13)  10.031838     0.830662
# 101   Reported value of upwards transition as 0.103(4)   6.447768     0.250399
# 102                                                NaN        NaN          NaN
# 103    Reported value of upwards transition as 0.40(3)  23.114473     1.733585
# 104                                                NaN        NaN          NaN
# 105    Reported value of upwards transition as 0.63(7)  34.354711     3.817190
# 106    Reported value of upwards transition as 0.66(4)  38.138880     2.311447
# 107    Reported value of upwards transition as 0.64(4)  36.268523     2.266783
# 108   Reported value of upwards transition as 0.611(9)  33.962440     0.500265
# 109   Reported value of upwards transition as 0.47(11)  26.124954     6.114351
# 110   Reported value of upwards transition as 1.10(11)  51.791698     5.179170
# 111    Reported value of upwards transition as 0.64(6)  29.094349     2.727595
# 112    Reported value of upwards transition as 0.59(7)  25.912221     3.074331
# 113    Reported value of upwards transition as 0.70(5)  30.224448     2.158889
# 114  Reported value of upwards transition as 0.570(36)  24.199438     1.528386
# 115   Reported value of upwards transition as 0.71(12)  30.143160     5.094619
# 116    Reported value of upwards transition as 0.41(6)  17.117712     2.505031
# 117    Reported value of upwards transition as 0.42(7)  17.246576     2.874429
# 118   Reported value of upwards transition as 0.41(10)  16.031156     3.910038
# 119  Reported value of upwards transition as 0.202(20)   7.772410     0.769546

# %%
# Extract the data from experimental or computed
exp = []
expN = []
expZ = []
experr = []

com = []
comN = []
comZ = []
comerr = []

for i in range(len(BE3)):
    
    if BE3["BE3"].iloc[i] != ".":
        
        expN.append(float(BE3["n"].iloc[i]))
        expZ.append(float(BE3["z"].iloc[i]))
        exp.append(float(BE3["BE3"].iloc[i]))
        errorstr = BE3["BE3unc"].iloc[i]
        
        if len(errorstr.split("–")) == 2:
            experr.append([float(errorstr.split("–")[0]), float(errorstr.split("–")[1])])
        else:
            experr.append([float(errorstr), float(errorstr)])
            
    else:
        comN.append(float(BE3["n"].iloc[i]))
        comZ.append(float(BE3["z"].iloc[i]))
        com.append(BE3["Computed"].iloc[i])
        comerr.append([BE3["ComputedErr"].iloc[i], BE3["ComputedErr"].iloc[i]])

# %%
plt.figure(figsize=(15,8))
plt.errorbar(expN, exp, yerr=np.array(experr).T, fmt='o', ecolor = 'C0', capsize=4, label = r"Reported $3^-\rightarrow 0^+$ transition")
plt.errorbar(comN, com, yerr=np.array(comerr).T, fmt='o', color = 'C1', ecolor = 'C1', capsize=4, label = r"Derived from $0^+\rightarrow 3^-$ transition")

plt.ylabel(r"$B(E3;3^-_{1}\rightarrow 0^+_{1})$  [W.u.]", fontsize=20)
plt.xlabel("N", fontsize=20)

# Octupole magic numbers from Martinou & Minkov, Phys. Scr. 99 075311
OMN = [32, 56, 90, 134]#194
for mn in OMN:
    plt.vlines(mn, 0.7,2000, colors="gray", alpha=0.7, linestyles="dashed")
    plt.text(mn+1, 0.8, "N = "+str(mn), fontsize = 15)

plt.yscale("log")
plt.xticks(np.arange(5, 160, step=5))
plt.grid(alpha=0.3)
plt.ylim(0.7,2000)
plt.legend(fontsize = 15)
plt.savefig('BE3N.png', format='png', dpi=800)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.errorbar(expZ, exp, yerr=np.array(experr).T, fmt='o', ecolor = 'C0', capsize=4, label = r"Reported $3^-\rightarrow 0^+$ transition")
plt.errorbar(comZ, com, yerr=np.array(comerr).T, fmt='o', color = 'C1', ecolor = 'C1', capsize=4, label = r"Derived from $0^+\rightarrow 3^-$ transition")

plt.ylabel(r"$B(E3;3^-_{1}\rightarrow 0^+_{1})$  [W.u.]", fontsize=20)
plt.xlabel("Z", fontsize=20)

# Octupole magic numbers from Martinou & Minkov, Phys. Scr. 99 075311
OMN = [32, 56, 90] #134]#194
for mn in OMN:
    plt.vlines(mn, 0.7,2000, colors="gray", alpha=0.7, linestyles="dashed")
    plt.text(mn+1, 0.8, "Z = "+str(mn), fontsize = 15)

plt.yscale("log")
plt.xticks(np.arange(5, 105, step=5))
plt.grid(alpha=0.3)
plt.ylim(0.7,2000)
plt.legend(fontsize = 15)
plt.savefig('BE3Z.png', format='png', dpi=800)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.errorbar(np.array(expZ)+np.array(expN), exp, yerr=np.array(experr).T, fmt='o', ecolor = 'C0', capsize=4, label = r"Reported $3^-\rightarrow 0^+$ transition")
plt.errorbar(np.array(comZ)+np.array(comN), com, yerr=np.array(comerr).T, fmt='o', color = 'C1', ecolor = 'C1', capsize=4, label = r"Derived from $0^+\rightarrow 3^-$ transition")

plt.ylabel(r"$B(E3;3^-_{1}\rightarrow 0^+_{1})$  [W.u.]", fontsize=20)
plt.xlabel("A", fontsize=20)

plt.yscale("log")
plt.xticks(np.arange(10, 260, step=10))
plt.grid(alpha=0.3)
plt.ylim(0.7,2000)
plt.legend()
plt.savefig('BE3A.png', format='png', dpi=800)
plt.show()

# %% [markdown]
# # Values of  $E_{3_1^-}$

# %%
first3 = pd.read_csv("First_3_minus_EvenEven.csv")
first3["a"] = first3["n"] + first3["z"]

# %%
first3.sort_values(by=["firstThreeMinusEnergy(keV)"]).head(12)
# Lowest values: 224Ra, 224Th (Quartet), 226Th, 222Ra, 226Ra, 228Th, 230U, 222Th, 220Ra (Quartet), 228Ra, 230Th, 232Th
# Out:
#       z    n  firstThreeMinusEnergy(keV)    a
# 298  88  136                     290.352  224
# 296  90  134                     305.300  224
# 299  90  136                     307.500  226
# 295  88  134                     317.290  222
# 301  88  138                     321.540  226
# 302  90  138                     396.094  228
# 303  92  138                     435.190  230
# 293  90  132                     467.000  222
# 292  88  132                     474.170  220
# 304  88  140                     537.500  228
# 305  90  140                     571.756  230
# 306  92  140                     628.965  232

# %%
#%matplotlib notebook

# Data
N = first3["n"].to_numpy()
Z = first3["z"].to_numpy()
E = first3["firstThreeMinusEnergy(keV)"].to_numpy()
magic = [2, 8, 20, 28, 50, 82, 126]

# Canvas
fig = plt.figure(figsize = (15,15))
ax = plt.axes(projection ="3d")
 
#Plots
ax.scatter(N, Z, E, "o", s= 10, c = "C0", alpha=1)
ax.scatter(N, Z, 0, "o", s= 10, c = "C0", alpha=0.5)
ax.scatter(N, max(Z), E, "o", s= 10, c = "C1", alpha=1)
ax.scatter(min(N), Z, E, "o", s= 10, c = "C2", alpha=1)
for i in range(len(N)):
    ax.plot([N[i], N[i]], [Z[i], Z[i]], [E[i], 0], color='C0', alpha=0.1)  
#for i in range(len(magic)):
    #ax.plot([magic[i], magic[i]], [105, 105], [0, max(E)], color='C1', alpha=0.4)  
    #if i < len(magic)-1:
    #    ax.plot([0,0], [magic[i], magic[i]], [0, max(E)], color='C2', alpha=0.4)  

    
# Format the axis
ax.invert_xaxis()
ax.set_xlabel('N', fontsize=14, labelpad=10)
ax.set_ylabel('Z', fontsize=14, labelpad=10)
ax.set_zlabel(r'$E(3^{-}_1)$ [keV]', fontsize=14, labelpad=10, rotation=-180)
ax.view_init(35, -135) 
ax.set_xticks(np.arange(min(N), max(N)+10, 10))
ax.set_yticks(np.arange(min(Z), max(Z)+10, 10))
ax.set_zticks(np.arange(300, 9600, 1000))

# Plot the planes
X, Y = np.meshgrid(np.linspace(min(N), max(N), 10), np.linspace(min(Z), max(Z), 10))
Z_xy = np.zeros_like(X)
X_xz, Z_xz = np.meshgrid(np.linspace(min(N), max(N), 10), np.linspace(0, max(E), 10))
Y_xz = np.full((len(X_xz[0]), len(X_xz[0])), max(Z))
Y_yz, Z_yz = np.meshgrid(np.linspace(min(Z), max(Z), 10), np.linspace(0, max(E), 10))
X_yz = np.full((len(X_xz[0]), len(X_xz[0])), min(N))
ax.plot_surface(X, Y, Z_xy, color='blue', alpha=0.05, rstride=100, cstride=100)
ax.plot_surface(X_xz, Y_xz, Z_xz, color='red', alpha=0.05, rstride=100, cstride=100)
ax.plot_surface(X_yz, Y_yz, Z_yz, color='green', alpha=0.05, rstride=100, cstride=100)
ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))

# Maximum values
ax.set_xlim(max(N), min(N))
ax.set_ylim(min(Z), max(Z))
ax.set_zlim(min(E), max(E))

plt.show()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(first3["a"], first3["firstThreeMinusEnergy(keV)"], ".")
plt.show()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(first3["n"], first3["firstThreeMinusEnergy(keV)"], ".")
plt.show()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(first3["z"], first3["firstThreeMinusEnergy(keV)"], ".")
plt.show()
