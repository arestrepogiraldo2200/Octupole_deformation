# %%
# %run O_O_residual_interaction.ipynb
# Out:
# /tmp/ipykernel_1954013/279327973.py:3: DeprecationWarning: Using factorial() with floats is deprecated
#   return (-1)**k/math.factorial(abs(k)) * np.sqrt( (2*math.factorial(n)) / (math.gamma(n+l+3/2)) )* (math.gamma(n+l+3/2)) / (math.factorial(n-k)*math.gamma(k+l+3/2))
# /tmp/ipykernel_1954013/279327973.py:3: DeprecationWarning: Using factorial() with floats is deprecated
#   return (-1)**k/math.factorial(abs(k)) * np.sqrt( (2*math.factorial(n)) / (math.gamma(n+l+3/2)) )* (math.gamma(n+l+3/2)) / (math.factorial(n-k)*math.gamma(k+l+3/2))

# %% [markdown]
# # e.s. band

# %% [markdown]
# # Proton

# %%
# p1- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,1,1/2,1/2,0,0,0,0,0,1], [[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,1,1/2,1/2,0,0,0,0,0,1], inter, "e1"))
# Out:
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# p3- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,3,1/2,1/2,0,0,0,0,0,3], [[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,3,1/2,1/2,0,0,0,0,0,3], inter, "e3"))
# Out:
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# p5- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,5,1/2,1/2,0,0,0,0,0,5], [[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,5,1/2,1/2,0,0,0,0,0,5], inter, "e5"))
# Out:
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# p7- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,7,1/2,1/2,0,0,0,0,0,7], [[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,7,1/2,1/2,0,0,0,0,0,7], inter, "e7"))
# Out:
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# p9- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,9,1/2,1/2,0,0,0,0,0,9], [[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,9,1/2,1/2,0,0,0,0,0,9], inter, "e9"))
# Out:
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# p11- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,11,1/2,1/2,0,0,0,0,0,11], [[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,11,1/2,1/2,0,0,0,0,0,11], inter, "e1"))
# Out:
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# p13- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,13,1/2,1/2,0,0,0,0,0,13], [[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,13,1/2,1/2,0,0,0,0,0,13], inter, "e1"))
# Out:
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# p15- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,15,1/2,1/2,0,0,0,0,0,15], [[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,15,1/2,1/2,0,0,0,0,0,15], inter, "e1"))
# Out:
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# p17- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,17,1/2,1/2,0,0,0,0,0,17], [[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,17,1/2,1/2,0,0,0,0,0,17], inter, "e1"))
# Out:
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %% [markdown]
# # Neutron

# %%
# n1- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,1,0,0,1/2,1/2,0,0,0,1], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,1,0,0,1/2,1/2,0,0,0,1], inter, "e1"))
# Out:
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# n3- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,3,0,0,1/2,1/2,0,0,0,3], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,3,0,0,1/2,1/2,0,0,0,3], inter, "e3"))
# Out:
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# n5- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,5,0,0,1/2,1/2,0,0,0,5], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,5,0,0,1/2,1/2,0,0,0,5], inter, "e5"))
# Out:
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# n7- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,7,0,0,1/2,1/2,0,0,0,7], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,7,0,0,1/2,1/2,0,0,0,7], inter, "e7"))
# Out:
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# n9- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,9,0,0,1/2,1/2,0,0,0,9], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,9,0,0,1/2,1/2,0,0,0,9], inter, "e9"))
# Out:
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# n15- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,15,0,0,1/2,1/2,0,0,0,15], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,15,0,0,1/2,1/2,0,0,0,15], inter, "e1"))
# Out:
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# n17- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,17,0,0,1/2,1/2,0,0,0,17], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,17,0,0,1/2,1/2,0,0,0,17], inter, "e1"))
# Out:
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...
