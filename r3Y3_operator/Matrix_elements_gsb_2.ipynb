# %%
# %run O_O_residual_interaction.ipynb
# Out:
# /tmp/ipykernel_2680378/279327973.py:3: DeprecationWarning: Using factorial() with floats is deprecated
#   return (-1)**k/math.factorial(abs(k)) * np.sqrt( (2*math.factorial(n)) / (math.gamma(n+l+3/2)) )* (math.gamma(n+l+3/2)) / (math.factorial(n-k)*math.gamma(k+l+3/2))
# /tmp/ipykernel_2680378/279327973.py:3: DeprecationWarning: Using factorial() with floats is deprecated
#   return (-1)**k/math.factorial(abs(k)) * np.sqrt( (2*math.factorial(n)) / (math.gamma(n+l+3/2)) )* (math.gamma(n+l+3/2)) / (math.factorial(n-k)*math.gamma(k+l+3/2))

# %%
# 12+ matrix element
print(O_O_ReducedMatrixElement([[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,2],34,4,[0],0,0,0,34,4,0,60,8,1,12,0,0,0,0,0,0,0,12], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,2],34,4,[0],0,0,0,34,4,0,60,8,1,12,0,0,0,0,0,0,0,12], inter, "s1"))
# Out:
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# 14+ matrix element
print(O_O_ReducedMatrixElement([[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,2],34,4,[0],0,0,0,34,4,0,60,8,1,14,0,0,0,0,0,0,0,14], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,2],34,4,[0],0,0,0,34,4,0,60,8,1,14,0,0,0,0,0,0,0,14], inter, "s2"))
# Out:
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...
