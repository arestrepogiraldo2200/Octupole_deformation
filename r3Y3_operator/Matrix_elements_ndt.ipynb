# %%
# %run O_O_residual_interaction.ipynb
# Out:
# /tmp/ipykernel_2197425/279327973.py:3: DeprecationWarning: Using factorial() with floats is deprecated
#   return (-1)**k/math.factorial(abs(k)) * np.sqrt( (2*math.factorial(n)) / (math.gamma(n+l+3/2)) )* (math.gamma(n+l+3/2)) / (math.factorial(n-k)*math.gamma(k+l+3/2))
# /tmp/ipykernel_2197425/279327973.py:3: DeprecationWarning: Using factorial() with floats is deprecated
#   return (-1)**k/math.factorial(abs(k)) * np.sqrt( (2*math.factorial(n)) / (math.gamma(n+l+3/2)) )* (math.gamma(n+l+3/2)) / (math.factorial(n-k)*math.gamma(k+l+3/2))

# %% [markdown]
# # Non-diagonal terms

# %%
# pn1- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,1,1/2,1/2,0,0,0,0,0,1], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,1,0,0,1/2,1/2,0,0,0,1], inter, "n1"))
# Out:
# 0
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# Confirmation of hermiticity. Good!

# %%
# np1- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,1,0,0,1/2,1/2,0,0,0,1], [[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,1,1/2,1/2,0,0,0,0,0,1], inter, "n1"))
# Out:
# 0
# 0
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# pn3- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,3,1/2,1/2,0,0,0,0,0,3], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,3,0,0,1/2,1/2,0,0,0,3], inter, "n3"))
# Out:
# 0
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# pn5- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,5,1/2,1/2,0,0,0,0,0,5], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,5,0,0,1/2,1/2,0,0,0,5], inter, "n5"))
# Out:
# 0
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# pn7- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,7,1/2,1/2,0,0,0,0,0,7], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,7,0,0,1/2,1/2,0,0,0,7], inter, "n7"))
# Out:
# 0
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# pn9- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,9,1/2,1/2,0,0,0,0,0,9], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,9,0,0,1/2,1/2,0,0,0,9], inter, "n9"))
# Out:
# 0
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# pn11- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,11,1/2,1/2,0,0,0,0,0,11], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,11,0,0,1/2,1/2,0,0,0,11], inter, "n1"))
# Out:
# 0
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# pn13- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,13,1/2,1/2,0,0,0,0,0,13], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,13,0,0,1/2,1/2,0,0,0,13], inter, "n1"))
# Out:
# 0
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# pn15- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,15,1/2,1/2,0,0,0,0,0,15], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,15,0,0,1/2,1/2,0,0,0,15], inter, "n1"))
# Out:
# 0
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# pn17- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,17,1/2,1/2,0,0,0,0,0,17], [[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,17,0,0,1/2,1/2,0,0,0,17], inter, "n1"))
# Out:
# 0
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...

# %%
# Confirmation of hermiticity. Good!

# %%
# np7- matrix element
print(O_O_ReducedMatrixElement([[2,2,2,2],26,4,[0],0,0,0,26,4,[2,2,2,1],32,2,[1],7,0,0,39,2,0,65,6,1,7,0,0,1/2,1/2,0,0,0,7], [[2,2,2,1],25,2,[1],6,0,0,31,2,[2,2,2,2],34,4,[0],0,0,0,34,4,0,65,6,1,7,1/2,1/2,0,0,0,0,0,7], inter, "n7"))
# Out:
# 0
# 0
# 0
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
#  ***** XEWU3 DIMENSION OVERFLOW ==============================================================
# ...
